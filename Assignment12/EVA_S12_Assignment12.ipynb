# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidmeras/EVA_PHASE1/blob/master/Assignment12/EVA_S12_Assignment12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EVA Session12 Assignment 12:
#
# Objective:
#
# To train the network incorporating OneCycleLR technique.

# %% [markdown]
# # # 1. Import APIs and library

# %%
import time
import math
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(24072019) 
from keras.models import Sequential, Model, load_model
from keras.layers.convolutional import MaxPooling2D, SeparableConv2D, Convolution2D, Conv2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dropout, Input, Lambda
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras import regularizers
from keras import backend as K

from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler
from keras.layers.advanced_activations import ReLU
import tensorflow as tf
from keras.layers.merge import concatenate

import cv2
from keras.preprocessing import image
from google.colab.patches import cv2_imshow

import matplotlib.gridspec as gridspec

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# # # 2. Define helper functions:
#
#
# 1.   get_cifar10_data
# 2.   get_cifar10_labels
# 3.   show_examples
# 4.   plot_model_history
# 5.   get_cutout_eraser

# %%
def get_cifar10_data():
    from keras.datasets import cifar10
    (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
    num_train, img_channels, img_rows, img_cols =  train_features.shape
    num_test, _, _, _ =  test_features.shape
    num_classes = len(np.unique(train_labels))

    # Flatten 32x32x3 images to a 1024*3 vector for each image.
    train_features = train_features.reshape(train_features.shape[0], 32, 32, 3)
    test_features = test_features.reshape(test_features.shape[0], 32, 32, 3)

    train_features = train_features.astype('float32')/255
    test_features = test_features.astype('float32')/255

    # convert class labels to binary class labels
    train_labels = np_utils.to_categorical(train_labels, num_classes)
    test_labels = np_utils.to_categorical(test_labels, num_classes)
    return (train_features, train_labels), (test_features, test_labels)

def get_cifar10_labels():
    class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
    return class_names

def show_examples(X,y,classes):
    rows = int(np.ceil(len(X)/5))
    if X.shape[1] > 64:
        multiplier = 2
    else:
        multiplier = 1
    fig = plt.figure(figsize=(10*multiplier, rows*2*multiplier))
    for idx in np.arange(len(X)):
        img = X[idx]
        assert (len(img.shape)==3 and img.shape[2] in [1,3,4]) or len(img.shape)==2
        ax = fig.add_subplot(rows, 5, idx + 1, xticks=[], yticks=[])
        cmap = None
        if (len(img.shape)==3 and img.shape[2]==1) or len(img.shape)==2:
            cmap="binary"
        if len(img.shape)==3 and img.shape[2]==1:
            img = img.reshape((img.shape[0],img.shape[1]))
        ax.imshow(img,cmap=cmap)
        ax.set_title(classes[np.argmax(y[idx])])
    plt.show()
        
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()    
        
# Cut-out
def get_cutout_eraser(p=0.5, s_l=0.05, s_h=0.3, r_1=0.3, r_2=1 / 0.3, max_erasures_per_image=1, pixel_level=True):
  
    """
    :param p:
    :param s_l: Minimum Area Proportion of Original that may be cut
    :param s_h: Maximum Area Proportion of Original that may be cut
    :param r_1: Min Aspect Ratio
    :param r_2: Max Aspect Ratio
    :param max_erasures_per_image:
    :param pixel_level:
    :return: Eraser to be used as Preprocessing Function
    """
    assert max_erasures_per_image >= 1

    def eraser(input_img):
        v_l = np.min(input_img)
        v_h = np.max(input_img)
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        mx = np.random.randint(1, max_erasures_per_image + 1)
        # print("Erasures = ",mx,end =", ")
        for i in range(mx):
            while True:
                s = np.random.uniform(s_l, s_h) * img_h * img_w
                r = np.random.uniform(r_1, r_2)
                w = int(np.sqrt(s / r))
                h = int(np.sqrt(s * r))
                left = np.random.randint(0, img_w)
                top = np.random.randint(0, img_h)

                if left + w <= img_w and top + h <= img_h:
                    break

            # print("W = ",w,"H = ",h,end =", ")

            if pixel_level:
                # print(np.max(img_c),np.min(img_c),v_l,v_h)
                c = np.random.uniform(v_l, v_h, (h, w, img_c))
                # print(c.shape,np.min(c),np.max(c),np.median(c))
            else:
                c = np.random.uniform(v_l, v_h)

            input_img[top:top + h, left:left + w, :] = c

        # print()
        return input_img

    return eraser
  
# Min-Max scale  
def min_max_scale(X):
    return (X - np.min(X))/(np.max(X)-np.min(X))  
  
def denormalize(img):
  return (img*datagen_validation.std + datagen_validation.mean)/255  

# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %% [markdown]
# # # 3. OneCycleLR class

# %%
import os
import numpy as np
import warnings

from keras.callbacks import Callback
from keras import backend as K


# Code is ported from https://github.com/fastai/fastai
class OneCycleLR(Callback):
    def __init__(self,
                 epochs,
                 batch_size,
                 samples,
                 steps,
                 max_lr,
                 end_percentage=0.1,
                 scale_percentage=None,
                 maximum_momentum=0.95,
                 minimum_momentum=0.85,
                 verbose=True):
        """ This callback implements a cyclical learning rate policy (CLR).
        This is a special case of Cyclic Learning Rates, where we have only 1 cycle.
        After the completion of 1 cycle, the learning rate will decrease rapidly to
        100th its initial lowest value.
        # Arguments:
            max_lr: Float. Initial learning rate. This also sets the
                starting learning rate (which will be 10x smaller than
                this), and will increase to this value during the first cycle.
            end_percentage: Float. The percentage of all the epochs of training
                that will be dedicated to sharply decreasing the learning
                rate after the completion of 1 cycle. Must be between 0 and 1.
            scale_percentage: Float or None. If float, must be between 0 and 1.
                If None, it will compute the scale_percentage automatically
                based on the `end_percentage`.
            maximum_momentum: Optional. Sets the maximum momentum (initial)
                value, which gradually drops to its lowest value in half-cycle,
                then gradually increases again to stay constant at this max value.
                Can only be used with SGD Optimizer.
            minimum_momentum: Optional. Sets the minimum momentum at the end of
                the half-cycle. Can only be used with SGD Optimizer.
            verbose: Bool. Whether to print the current learning rate after every
                epoch.
        # Reference
            - [A disciplined approach to neural network hyper-parameters: Part 1 -- learning rate, batch size, weight_decay, and weight decay](https://arxiv.org/abs/1803.09820)
            - [Super-Convergence: Very Fast Training of Residual Networks Using Large Learning Rates](https://arxiv.org/abs/1708.07120)
        """
        super(OneCycleLR, self).__init__()

        if end_percentage < 0. or end_percentage > 1.:
            raise ValueError("`end_percentage` must be between 0 and 1")

        if scale_percentage is not None and (scale_percentage < 0. or scale_percentage > 1.):
            raise ValueError("`scale_percentage` must be between 0 and 1")

        self.initial_lr = max_lr
        self.end_percentage = end_percentage
        self.scale = float(scale_percentage) if scale_percentage is not None else float(end_percentage)
        self.max_momentum = maximum_momentum
        self.min_momentum = minimum_momentum
        self.verbose = verbose

        if self.max_momentum is not None and self.min_momentum is not None:
            self._update_momentum = True
        else:
            self._update_momentum = False

        self.clr_iterations = 0.
        self.history = {}

        self.epochs = epochs
        self.batch_size = batch_size
        self.samples = samples
        self.steps = steps
        self.num_iterations = None
        self.mid_cycle_id = None

    def _reset(self):
        """
        Reset the callback.
        """
        self.clr_iterations = 0.
        self.history = {}

    def compute_lr(self):
        """
        Compute the learning rate based on which phase of the cycle it is in.
        - If in the first half of training, the learning rate gradually increases.
        - If in the second half of training, the learning rate gradually decreases.
        - If in the final `end_percentage` portion of training, the learning rate
            is quickly reduced to near 100th of the original min learning rate.
        # Returns:
            the new learning rate
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            current_percentage = (self.clr_iterations - 2 * self.mid_cycle_id)
            current_percentage /= float((self.num_iterations - 2 * self.mid_cycle_id))
            new_lr = self.initial_lr * (1. + (current_percentage *
                                              (1. - 100.) / 100.)) * self.scale

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - (
                    self.clr_iterations - self.mid_cycle_id) / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        else:
            current_percentage = self.clr_iterations / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        if self.clr_iterations == self.num_iterations:
            self.clr_iterations = 0

        return new_lr

    def compute_momentum(self):
        """
         Compute the momentum based on which phase of the cycle it is in.
        - If in the first half of training, the momentum gradually decreases.
        - If in the second half of training, the momentum gradually increases.
        - If in the final `end_percentage` portion of training, the momentum value
            is kept constant at the maximum initial value.
        # Returns:
            the new momentum value
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            new_momentum = self.max_momentum

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - ((self.clr_iterations - self.mid_cycle_id) / float(
                self.mid_cycle_id))
            new_momentum = self.max_momentum - current_percentage * (
                    self.max_momentum - self.min_momentum)

        else:
            current_percentage = self.clr_iterations / float(self.mid_cycle_id)
            new_momentum = self.max_momentum - current_percentage * (
                    self.max_momentum - self.min_momentum)

        return new_momentum

    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.steps is not None:
            self.num_iterations = self.epochs * self.steps
        else:
            if (self.samples % self.batch_size) == 0:
                remainder = 0
            else:
                remainder = 1
            self.num_iterations = (self.epochs + remainder) * self.samples // self.batch_size

        self.mid_cycle_id = int(self.num_iterations * ((1. - self.end_percentage)) / float(2))

        self._reset()
        K.set_value(self.model.optimizer.lr, self.compute_lr())

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()
            K.set_value(self.model.optimizer.momentum, new_momentum)

    def on_batch_end(self, epoch, logs=None):
        logs = logs or {}

        self.clr_iterations += 1
        new_lr = self.compute_lr()

        self.history.setdefault('lr', []).append(
            K.get_value(self.model.optimizer.lr))
        K.set_value(self.model.optimizer.lr, new_lr)

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()

            self.history.setdefault('momentum', []).append(
                K.get_value(self.model.optimizer.momentum))
            K.set_value(self.model.optimizer.momentum, new_momentum)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        if self.verbose:
            if self._update_momentum:
                print(" - lr: %0.5f - momentum: %0.2f " %
                      (self.history['lr'][-1], self.history['momentum'][-1]))

            else:
                print(" - lr: %0.5f " % (self.history['lr'][-1]))

# %% [markdown]
# # # 4. LR Finder class

# %%
import os
import numpy as np
import warnings

from keras.callbacks import Callback
from keras import backend as K

import numpy as np
import scipy.ndimage.filters as filters
import scipy.ndimage.morphology as morphology
import pandas as pd


def detect_local_minima(arr):
    # https://stackoverflow.com/questions/4624970/finding-local-maxima-minima-with-numpy-in-a-1d-numpy-array
    # https://stackoverflow.com/questions/3986345/how-to-find-the-local-minima-of-a-smooth-multidimensional-array-in-numpy-efficien
    # https://stackoverflow.com/questions/3684484/peak-detection-in-a-2d-array/3689710#3689710
    """
    Takes an array and detects the troughs using the local maximum filter.
    Returns a boolean mask of the troughs (i.e. 1 when
    the pixel's value is the neighborhood maximum, 0 otherwise)
    """
    # define an connected neighborhood
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#generate_binary_structure
    neighborhood = morphology.generate_binary_structure(len(arr.shape), 2)
    # apply the local minimum filter; all locations of minimum value
    # in their neighborhood are set to 1
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.filters.html#minimum_filter
    local_min = (filters.minimum_filter(arr, footprint=neighborhood) == arr)
    # local_min is a mask that contains the peaks we are
    # looking for, but also the background.
    # In order to isolate the peaks we must remove the background from the mask.
    #
    # we create the mask of the background
    background = (arr == 0)
    #
    # a little technicality: we must erode the background in order to
    # successfully subtract it from local_min, otherwise a line will
    # appear along the background border (artifact of the local minimum filter)
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#binary_erosion
    eroded_background = morphology.binary_erosion(
        background, structure=neighborhood, border_value=1)
    #
    # we obtain the final mask, containing only peaks,
    # by removing the background from the local_min mask
    detected_minima = local_min ^ eroded_background
    return np.where(detected_minima)


def moving_average_fast(x, w):
    # https://stackoverflow.com/questions/14313510/how-to-calculate-moving-average-using-numpy
    return np.convolve(np.array(x), np.ones(w), 'same') / w


def moving_average(x, w):
    df = pd.DataFrame({"x": x})
    return df.rolling(w, win_type=None, min_periods=1, center=True).mean()['x'].values


from matplotlib import pyplot as plt
import math
from keras.callbacks import LambdaCallback
import keras.backend as K
import numpy as np


class LRFinder:
    """
    Plots the change of the loss function of a Keras model when the learning rate is exponentially increasing.
    See for details:
    https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
    """

    def __init__(self, model, num_validation_batches=10):
        self.model = model
        self.losses = []
        self.lrs = []
        self.best_loss = 1e9
        self.num_validation_batches = num_validation_batches
        self.validation_set = None
        self.validation_generator = None

    def on_batch_end(self, batch, logs):
        # Log the learning rate
        lr = K.get_value(self.model.optimizer.lr)
        self.lrs.append(lr)

        # Log the loss

        if self.validation_set is not None:
            X, Y = self.validation_set[0], self.validation_set[1]

            # use 10 random batches from test set for fast approximate of loss
            num_samples = self.batch_size * self.num_validation_batches

            if num_samples > X.shape[0]:
                num_samples = X.shape[0]

            idx = np.random.choice(X.shape[0], num_samples, replace=False)
            x = X[idx]
            y = Y[idx]

            values = self.model.evaluate(x, y, batch_size=self.batch_size, verbose=False)
            loss = values[0]
        elif self.validation_generator is not None:
            values = self.model.evaluate_generator(self.validation_generator, steps=self.num_validation_batches, )
            # print(values[0],logs['loss'])
            loss = values[0]
        else:
            loss = logs['loss']

        self.losses.append(loss)

        # Check whether the loss got too large or NaN
        if batch > 10 and (math.isnan(loss) or loss > self.best_loss * 8):
            self.model.stop_training = True
            print("Stop Training at %s, loss = %.3f" % (batch, loss))
            return

        if loss < self.best_loss:
            self.best_loss = loss

        # Increase the learning rate for the next batch
        lr *= self.lr_mult
        K.set_value(self.model.optimizer.lr, lr)

    def find(self, x_train, y_train, start_lr, end_lr,
             x_test=None, y_test=None,
             batch_size=64, epochs=1):
        num_batches = epochs * x_train.shape[0] / batch_size
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(num_batches))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch, logs: self.on_batch_end(batch, logs))
        self.validation_set = (x_test, y_test) if x_test is not None and y_test is not None else None
        self.batch_size = batch_size

        self.model.fit(x_train, y_train,
                       batch_size=batch_size, epochs=epochs,
                       verbose=0,
                       callbacks=[callback])

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def find_generator(self, generator, start_lr, end_lr,
                       test_generator=None,
                       epochs=1, steps_per_epoch=None, **kw_fit):
        if steps_per_epoch is None:
            try:
                steps_per_epoch = len(generator)
            except (ValueError, NotImplementedError) as e:
                raise e('`steps_per_epoch=None` is only valid for a'
                        ' generator based on the '
                        '`keras.utils.Sequence`'
                        ' class. Please specify `steps_per_epoch` '
                        'or use the `keras.utils.Sequence` class.')
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(steps_per_epoch * epochs))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch,
                                                      logs: self.on_batch_end(batch, logs))

        self.validation_generator = test_generator

        self.model.fit_generator(generator=generator,
                                 epochs=epochs,
                                 steps_per_epoch=steps_per_epoch,
                                 callbacks=[callback],
                                 verbose=0,
                                 **kw_fit)

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def plot_loss(self, n_skip_beginning=5, n_skip_end=5, sma=10):
        """
        Plots the loss.
        Parameters:
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
        """
        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_subplot(111)
        plt.ylabel("loss")
        plt.xlabel("learning rate (log scale)")

        losses = self.losses
        losses = moving_average(losses, sma)

        losses = losses[n_skip_beginning:-n_skip_end]

        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], losses)
        plt.xscale('log')
        best_lrs = self.get_best_lrs(sma)
        lrs = [x for x, _ in best_lrs]
        positions = [x for _, x in best_lrs]
        # https://matplotlib.org/users/annotations_intro.html
        for lr, pos in [best_lrs[-1]]:
            ax.annotate('LR = %.3f, Loss = %.3f' % (lr, losses[pos]), xy=(lr, losses[pos]),
                        xytext=(lr + 0.2, losses[pos] + 0.1),
                        arrowprops=dict(facecolor='black', shrink=0.03, width=1, frac=0.05),
                        )

        title = "LR-Loss Graph"
        title = title + "\n" + "Best Candidate LR = %s" % lrs
        title = title + "\n" + "These Candidate LRs denote the positions of minima/troughs in LR-Loss graph"
        plt.title(title)
        plt.show()

    def get_derivatives(self, sma=10):
        assert sma >= 1
        derivatives = [0] * sma
        losses = moving_average(self.losses, 5)
        for i in range(sma, len(self.lrs)):
            derivatives.append((losses[i] - losses[i - sma]) / sma)
        return derivatives

    def __get_best_lr_method1__(self, sma, n_skip_beginning=10, n_skip_end=5):
        derivatives = self.get_derivatives(sma)
        losses = np.array(self.losses[n_skip_beginning:-n_skip_end])
        derivatives = derivatives[n_skip_beginning:-n_skip_end]
        lrs = self.lrs[n_skip_beginning:-n_skip_end]

        idxs = np.where(losses >= self.best_loss * 2)[0]
        idxs = idxs[0]
        derivatives = derivatives[:idxs + sma]
        losses = losses[:idxs + sma]
        lrs = lrs[:idxs + sma]

        best_idxs = np.argpartition(derivatives[:idxs], -5)[-5:]
        best_idxs = best_idxs - sma
        acceptable_loss_or_not = losses[best_idxs] <= self.best_loss * 4
        best_idxs = best_idxs[acceptable_loss_or_not]

        acceptable_loss_or_not = losses[best_idxs + sma] > (losses[best_idxs] * 1.05)
        best_idxs = best_idxs[acceptable_loss_or_not]

        candidates = list(np.array(lrs)[best_idxs])
        return sorted(candidates), best_idxs

    def get_best_lrs(self, sma, n_skip_beginning=10, n_skip_end=5):
        c1, i1 = self.__get_best_lr_method1__(sma, n_skip_beginning, n_skip_end)
        candidates = list(zip(c1, i1))
        candidates = sorted(candidates, key=lambda pair: pair[0])
        final_candidates = [candidates[0]]
        for v, i in candidates:
            if (v - final_candidates[-1][0]) / final_candidates[-1][0] > 0.2:
                final_candidates.append((v, i))
        final_candidates = list(map(lambda pair: (float("%.3f" % pair[0]), pair[1]), final_candidates))
        return final_candidates

# %% [markdown]
# # # 5. Normalization

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 128

#  load cifar10 data  
(train_features, train_labels), (test_features, test_labels) = get_cifar10_data()

cutout_fn = get_cutout_eraser(p=0.75, s_l=0.1, s_h=0.3, r_1=0.3, r_2=1 / 0.3, max_erasures_per_image=2, pixel_level=True)

datagen = ImageDataGenerator(featurewise_center=True,
                             featurewise_std_normalization=True,                              
#                              rotation_range=0,       # randomly rotate images in the range (degrees, 0 to 180)
#                              width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#                              height_shift_range=0.1, # randomly shift images vertically (fraction of total height)
#                              horizontal_flip=True,   # randomly flip images
#                              vertical_flip=False,    # randomly flip images                             
                             preprocessing_function=cutout_fn)
datagen.fit(train_features)

datagen_validation = ImageDataGenerator(featurewise_center=True,
                                        featurewise_std_normalization=True,
#                                         rotation_range=0,       # randomly rotate images in the range (degrees, 0 to 180)
#                                         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#                                         height_shift_range=0.1, # randomly shift images vertically (fraction of total height)
#                                         horizontal_flip=True,   # randomly flip images
#                                         vertical_flip=False,    # randomly flip images                                            
                                       )
datagen_validation.fit(train_features)


# train_features_mean = np.mean(train_features, axis=(0,1,2))
# train_features_std  = np.std(train_features, axis=(0,1,2))

# train_features = (train_features - train_features_mean) / train_features_std
# test_features  = (test_features - train_features_mean) / train_features_std

show_examples(train_features[0:10], train_labels[0:10], classes=get_cifar10_labels())

# %% [markdown]
# # # 6. Implement the function to create the model

# %%
# Define the model
def build_model(summary=False, lrate=0.0):
    
    input = Input(shape=(32, 32, 3,))
        
    x = Convolution2D(32, 3, 3, border_mode='same',kernel_regularizer=regularizers.l2(0.0001), input_shape=(32, 32, 3)) (input)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same') (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = MaxPooling2D(pool_size=(2, 2)) (x)
    x = Dropout(0.2) (x)

    x = Convolution2D(32, 1, 1) (x)


    x = Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same') (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same') (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = MaxPooling2D(pool_size=(2, 2)) (x)
    x = Dropout(0.3) (x)

    x = Convolution2D(32, 1, 1) (x)

    x = Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same') (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = Convolution2D(256, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same') (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x)

    x = MaxPooling2D(pool_size=(2, 2)) (x)
    x = Dropout(0.5) (x)

    x = Convolution2D(10, 1, 1) (x)

    x = AveragePooling2D(pool_size = (4,4)) (x)
    x = Flatten() (x)

    output = Activation('softmax') (x)
    
    model = Model(inputs=[input], outputs=[output])
    
    sgd = SGD(lr=lrate, momentum=0.9, decay=0.0, nesterov=False)
  
    model.compile(optimizer= sgd,
                  loss = 'binary_crossentropy',
                  metrics=['accuracy'])    
    
    #Print model summary
    if (summary == True):
        model.summary()
        i=0
        for layer in model.layers[0:]:
            if "conv" in layer.name:
                print ("Layer No.:", i, " Name:", layer.name)
                i+=1        
    
    return model

# %% [markdown]
# # # 7. Implement the function to train the network

# %%
def train_network(model, epochs=25, lr_scheduling_fn=None, one_cycle_start_lr=None, step_decay_lr=False):
      
    save_mcp = ModelCheckpoint('best_model_Ass11.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
          
    train_iterator      = datagen.flow(train_features, train_labels, batch_size=batch_size, shuffle=True)
    validation_iterator = datagen_validation.flow(test_features, test_labels, batch_size=batch_size, shuffle=True)
    
    callbacks=[save_mcp]
    lr_schedule = LearningRateScheduler(lr_scheduling_fn) if lr_scheduling_fn is not None else None
    
    lr_step = LearningRateScheduler(step_decay) if step_decay_lr is True else None
    
    if lr_schedule is not None:
       callbacks.append(lr_schedule)
        
    if lr_step is not None:
      callbacks.append(lr_step)      
        
    ################OneCycleLR###################################        
    if one_cycle_start_lr is not None:             
      lr_one_cycle = OneCycleLR(epochs=epochs,
                                batch_size=batch_size,
                                samples = len(test_labels),
                                steps = len(train_iterator),
                                max_lr=one_cycle_start_lr)  
      callbacks.append(lr_one_cycle) 
    #############################################################        
    
    # Train the model
    start = time.time() 
                              
    train_history = model.fit_generator(train_iterator,
                                        steps_per_epoch  = len(train_iterator), 
                                        validation_data  = validation_iterator, 
                                        validation_steps = len(validation_iterator),
                                        epochs           = epochs, 
                                        verbose          = 2,
                                        callbacks        = callbacks)    

    model.load_weights("best_model_Ass11.h5")
      
    end = time.time()
    print ("Model took %0.2f seconds to train \n"%(end - start))

    # plot model history
    if (epochs > 1):
        plot_model_history(train_history)

    return train_history

# %% [markdown]
# # # 8. Build the model

# %%
model = build_model(summary=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 08:16:49.539999 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 08:16:49.562245 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 08:16:49.565543 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 08:16:49.601987 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0731 08:16:49.603395 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0731 08:16:50.073412 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0731 08:16:50.254369 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0731 08:16:50.264799 139889163433856 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 08:16:50.775884 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0731 08:16:50.804538 139889163433856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0731 08:16:50.818190 139889163433856 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         36992
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 10)          2570
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 455,370
# Trainable params: 454,026
# Non-trainable params: 1,344
# _________________________________________________________________
# Layer No.: 0  Name: conv2d_1
# Layer No.: 1  Name: conv2d_2
# Layer No.: 2  Name: conv2d_3
# Layer No.: 3  Name: conv2d_4
# Layer No.: 4  Name: conv2d_5
# Layer No.: 5  Name: conv2d_6
# Layer No.: 6  Name: conv2d_7
# Layer No.: 7  Name: conv2d_8
# Layer No.: 8  Name: conv2d_9

# %% [markdown]
# # # 9. Dry run: Train the network for 100 epochs

# %%
train_history = train_network(model, epochs=100, step_decay_lr=True)
# Out:
# Epoch 1/100
#  - 28s - loss: 0.2869 - acc: 0.9068 - val_loss: 0.2437 - val_acc: 0.9198
#
# Epoch 00001: val_acc improved from -inf to 0.91981, saving model to best_model_Ass11.h5
# Epoch 2/100
#  - 24s - loss: 0.2372 - acc: 0.9214 - val_loss: 0.2308 - val_acc: 0.9244
#
# Epoch 00002: val_acc improved from 0.91981 to 0.92436, saving model to best_model_Ass11.h5
# Epoch 3/100
#  - 24s - loss: 0.2157 - acc: 0.9289 - val_loss: 0.1856 - val_acc: 0.9413
#
# Epoch 00003: val_acc improved from 0.92436 to 0.94128, saving model to best_model_Ass11.h5
# Epoch 4/100
#  - 24s - loss: 0.1980 - acc: 0.9346 - val_loss: 0.1674 - val_acc: 0.9471
#
# Epoch 00004: val_acc improved from 0.94128 to 0.94709, saving model to best_model_Ass11.h5
# Epoch 5/100
#  - 24s - loss: 0.1861 - acc: 0.9392 - val_loss: 0.1572 - val_acc: 0.9505
#
# Epoch 00005: val_acc improved from 0.94709 to 0.95048, saving model to best_model_Ass11.h5
# Epoch 6/100
#  - 24s - loss: 0.1776 - acc: 0.9418 - val_loss: 0.1561 - val_acc: 0.9511
#
# Epoch 00006: val_acc improved from 0.95048 to 0.95112, saving model to best_model_Ass11.h5
# Epoch 7/100
#  - 24s - loss: 0.1709 - acc: 0.9448 - val_loss: 0.1463 - val_acc: 0.9533
#
# Epoch 00007: val_acc improved from 0.95112 to 0.95330, saving model to best_model_Ass11.h5
# Epoch 8/100
#  - 24s - loss: 0.1659 - acc: 0.9461 - val_loss: 0.1435 - val_acc: 0.9549
#
# Epoch 00008: val_acc improved from 0.95330 to 0.95488, saving model to best_model_Ass11.h5
# Epoch 9/100
#  - 24s - loss: 0.1603 - acc: 0.9486 - val_loss: 0.1416 - val_acc: 0.9552
#
# Epoch 00009: val_acc improved from 0.95488 to 0.95525, saving model to best_model_Ass11.h5
# Epoch 10/100
#  - 24s - loss: 0.1464 - acc: 0.9537 - val_loss: 0.1229 - val_acc: 0.9633
#
# Epoch 00010: val_acc improved from 0.95525 to 0.96328, saving model to best_model_Ass11.h5
# Epoch 11/100
#  - 24s - loss: 0.1419 - acc: 0.9550 - val_loss: 0.1225 - val_acc: 0.9632
#
# Epoch 00011: val_acc did not improve from 0.96328
# Epoch 12/100
#  - 24s - loss: 0.1389 - acc: 0.9562 - val_loss: 0.1213 - val_acc: 0.9638
#
# Epoch 00012: val_acc improved from 0.96328 to 0.96383, saving model to best_model_Ass11.h5
# Epoch 13/100
#  - 24s - loss: 0.1371 - acc: 0.9566 - val_loss: 0.1194 - val_acc: 0.9642
#
# Epoch 00013: val_acc improved from 0.96383 to 0.96416, saving model to best_model_Ass11.h5
# Epoch 14/100
#  - 24s - loss: 0.1340 - acc: 0.9578 - val_loss: 0.1130 - val_acc: 0.9668
#
# Epoch 00014: val_acc improved from 0.96416 to 0.96678, saving model to best_model_Ass11.h5
# Epoch 15/100
#  - 24s - loss: 0.1322 - acc: 0.9582 - val_loss: 0.1164 - val_acc: 0.9647
#
# Epoch 00015: val_acc did not improve from 0.96678
# Epoch 16/100
#  - 24s - loss: 0.1322 - acc: 0.9582 - val_loss: 0.1157 - val_acc: 0.9658
#
# Epoch 00016: val_acc did not improve from 0.96678
# Epoch 17/100
#  - 24s - loss: 0.1297 - acc: 0.9591 - val_loss: 0.1131 - val_acc: 0.9665
#
# Epoch 00017: val_acc did not improve from 0.96678
# Epoch 18/100
#  - 24s - loss: 0.1284 - acc: 0.9597 - val_loss: 0.1063 - val_acc: 0.9687
#
# Epoch 00018: val_acc improved from 0.96678 to 0.96866, saving model to best_model_Ass11.h5
# Epoch 19/100
#  - 24s - loss: 0.1272 - acc: 0.9602 - val_loss: 0.1193 - val_acc: 0.9647
#
# Epoch 00019: val_acc did not improve from 0.96866
# Epoch 20/100
#  - 24s - loss: 0.1183 - acc: 0.9636 - val_loss: 0.1011 - val_acc: 0.9701
#
# Epoch 00020: val_acc improved from 0.96866 to 0.97009, saving model to best_model_Ass11.h5
# Epoch 21/100
#  - 24s - loss: 0.1153 - acc: 0.9647 - val_loss: 0.0995 - val_acc: 0.9721
#
# Epoch 00021: val_acc improved from 0.97009 to 0.97214, saving model to best_model_Ass11.h5
# Epoch 22/100
#  - 24s - loss: 0.1139 - acc: 0.9649 - val_loss: 0.0986 - val_acc: 0.9717
#
# Epoch 00022: val_acc did not improve from 0.97214
# Epoch 23/100
#  - 24s - loss: 0.1123 - acc: 0.9656 - val_loss: 0.0995 - val_acc: 0.9715
#
# Epoch 00023: val_acc did not improve from 0.97214
# Epoch 24/100
#  - 24s - loss: 0.1102 - acc: 0.9664 - val_loss: 0.0972 - val_acc: 0.9725
#
# Epoch 00024: val_acc improved from 0.97214 to 0.97246, saving model to best_model_Ass11.h5
# Epoch 25/100
#  - 24s - loss: 0.1107 - acc: 0.9661 - val_loss: 0.0995 - val_acc: 0.9718
#
# Epoch 00025: val_acc did not improve from 0.97246
# Epoch 26/100
#  - 24s - loss: 0.1096 - acc: 0.9663 - val_loss: 0.0976 - val_acc: 0.9724
#
# Epoch 00026: val_acc did not improve from 0.97246
# Epoch 27/100
#  - 24s - loss: 0.1078 - acc: 0.9667 - val_loss: 0.1036 - val_acc: 0.9702
#
# Epoch 00027: val_acc did not improve from 0.97246
# Epoch 28/100
#  - 24s - loss: 0.1081 - acc: 0.9665 - val_loss: 0.1019 - val_acc: 0.9698
#
# Epoch 00028: val_acc did not improve from 0.97246
# Epoch 29/100
#  - 23s - loss: 0.1073 - acc: 0.9670 - val_loss: 0.0952 - val_acc: 0.9729
#
# Epoch 00029: val_acc improved from 0.97246 to 0.97285, saving model to best_model_Ass11.h5
# Epoch 30/100
#  - 24s - loss: 0.1011 - acc: 0.9696 - val_loss: 0.0899 - val_acc: 0.9746
#
# Epoch 00030: val_acc improved from 0.97285 to 0.97458, saving model to best_model_Ass11.h5
# Epoch 31/100
#  - 23s - loss: 0.0985 - acc: 0.9708 - val_loss: 0.0896 - val_acc: 0.9742
#
# Epoch 00031: val_acc did not improve from 0.97458
# Epoch 32/100
#  - 24s - loss: 0.0975 - acc: 0.9707 - val_loss: 0.0892 - val_acc: 0.9748
#
# Epoch 00032: val_acc improved from 0.97458 to 0.97478, saving model to best_model_Ass11.h5
# Epoch 33/100
#  - 23s - loss: 0.0961 - acc: 0.9711 - val_loss: 0.0906 - val_acc: 0.9745
#
# Epoch 00033: val_acc did not improve from 0.97478
# Epoch 34/100
#  - 24s - loss: 0.0965 - acc: 0.9710 - val_loss: 0.0875 - val_acc: 0.9755
#
# Epoch 00034: val_acc improved from 0.97478 to 0.97548, saving model to best_model_Ass11.h5
# Epoch 35/100
#  - 24s - loss: 0.0948 - acc: 0.9713 - val_loss: 0.0870 - val_acc: 0.9753
#
# Epoch 00035: val_acc did not improve from 0.97548
# Epoch 36/100
#  - 23s - loss: 0.0948 - acc: 0.9715 - val_loss: 0.0905 - val_acc: 0.9749
#
# Epoch 00036: val_acc did not improve from 0.97548
# Epoch 37/100
#  - 24s - loss: 0.0940 - acc: 0.9718 - val_loss: 0.0892 - val_acc: 0.9749
#
# Epoch 00037: val_acc did not improve from 0.97548
# Epoch 38/100
#  - 24s - loss: 0.0935 - acc: 0.9719 - val_loss: 0.0890 - val_acc: 0.9747
#
# Epoch 00038: val_acc did not improve from 0.97548
# Epoch 39/100
#  - 24s - loss: 0.0928 - acc: 0.9721 - val_loss: 0.0849 - val_acc: 0.9764
#
# Epoch 00039: val_acc improved from 0.97548 to 0.97636, saving model to best_model_Ass11.h5
# Epoch 40/100
#  - 24s - loss: 0.0888 - acc: 0.9736 - val_loss: 0.0847 - val_acc: 0.9768
#
# Epoch 00040: val_acc improved from 0.97636 to 0.97679, saving model to best_model_Ass11.h5
# Epoch 41/100
#  - 24s - loss: 0.0874 - acc: 0.9741 - val_loss: 0.0839 - val_acc: 0.9766
#
# Epoch 00041: val_acc did not improve from 0.97679
# Epoch 42/100
#  - 24s - loss: 0.0867 - acc: 0.9745 - val_loss: 0.0833 - val_acc: 0.9769
#
# Epoch 00042: val_acc improved from 0.97679 to 0.97693, saving model to best_model_Ass11.h5
# Epoch 43/100
#  - 23s - loss: 0.0855 - acc: 0.9749 - val_loss: 0.0836 - val_acc: 0.9771
#
# Epoch 00043: val_acc improved from 0.97693 to 0.97712, saving model to best_model_Ass11.h5
# Epoch 44/100
#  - 24s - loss: 0.0859 - acc: 0.9744 - val_loss: 0.0841 - val_acc: 0.9769
#
# Epoch 00044: val_acc did not improve from 0.97712
# Epoch 45/100
#  - 24s - loss: 0.0850 - acc: 0.9749 - val_loss: 0.0831 - val_acc: 0.9771
#
# Epoch 00045: val_acc did not improve from 0.97712
# Epoch 46/100
#  - 24s - loss: 0.0839 - acc: 0.9752 - val_loss: 0.0826 - val_acc: 0.9774
#
# Epoch 00046: val_acc improved from 0.97712 to 0.97742, saving model to best_model_Ass11.h5
# Epoch 47/100
#  - 24s - loss: 0.0843 - acc: 0.9749 - val_loss: 0.0845 - val_acc: 0.9765
#
# Epoch 00047: val_acc did not improve from 0.97742
# Epoch 48/100
#  - 24s - loss: 0.0834 - acc: 0.9753 - val_loss: 0.0828 - val_acc: 0.9766
#
# Epoch 00048: val_acc did not improve from 0.97742
# Epoch 49/100
#  - 24s - loss: 0.0833 - acc: 0.9753 - val_loss: 0.0828 - val_acc: 0.9768
#
# Epoch 00049: val_acc did not improve from 0.97742
# Epoch 50/100
#  - 24s - loss: 0.0809 - acc: 0.9764 - val_loss: 0.0814 - val_acc: 0.9773
#
# Epoch 00050: val_acc did not improve from 0.97742
# Epoch 51/100
#  - 24s - loss: 0.0799 - acc: 0.9768 - val_loss: 0.0817 - val_acc: 0.9775
#
# Epoch 00051: val_acc improved from 0.97742 to 0.97754, saving model to best_model_Ass11.h5
# Epoch 52/100
#  - 24s - loss: 0.0796 - acc: 0.9766 - val_loss: 0.0809 - val_acc: 0.9778
#
# Epoch 00052: val_acc improved from 0.97754 to 0.97779, saving model to best_model_Ass11.h5
# Epoch 53/100
#  - 24s - loss: 0.0792 - acc: 0.9769 - val_loss: 0.0807 - val_acc: 0.9780
#
# Epoch 00053: val_acc improved from 0.97779 to 0.97805, saving model to best_model_Ass11.h5
# Epoch 54/100
#  - 24s - loss: 0.0788 - acc: 0.9769 - val_loss: 0.0812 - val_acc: 0.9778
#
# Epoch 00054: val_acc did not improve from 0.97805
# Epoch 55/100
#  - 23s - loss: 0.0784 - acc: 0.9771 - val_loss: 0.0811 - val_acc: 0.9778
#
# Epoch 00055: val_acc did not improve from 0.97805
# Epoch 56/100
#  - 23s - loss: 0.0785 - acc: 0.9771 - val_loss: 0.0807 - val_acc: 0.9777
#
# Epoch 00056: val_acc did not improve from 0.97805
# Epoch 57/100
#  - 23s - loss: 0.0778 - acc: 0.9772 - val_loss: 0.0810 - val_acc: 0.9780
#
# Epoch 00057: val_acc did not improve from 0.97805
# Epoch 58/100
#  - 24s - loss: 0.0780 - acc: 0.9772 - val_loss: 0.0816 - val_acc: 0.9776
#
# Epoch 00058: val_acc did not improve from 0.97805
# Epoch 59/100
#  - 23s - loss: 0.0776 - acc: 0.9774 - val_loss: 0.0807 - val_acc: 0.9778
#
# Epoch 00059: val_acc did not improve from 0.97805
# Epoch 60/100
#  - 23s - loss: 0.0767 - acc: 0.9776 - val_loss: 0.0802 - val_acc: 0.9776
#
# Epoch 00060: val_acc did not improve from 0.97805
# Epoch 61/100
#  - 24s - loss: 0.0756 - acc: 0.9781 - val_loss: 0.0799 - val_acc: 0.9780
#
# Epoch 00061: val_acc did not improve from 0.97805
# Epoch 62/100
#  - 24s - loss: 0.0759 - acc: 0.9779 - val_loss: 0.0791 - val_acc: 0.9784
#
# Epoch 00062: val_acc improved from 0.97805 to 0.97838, saving model to best_model_Ass11.h5
# Epoch 63/100
#  - 24s - loss: 0.0753 - acc: 0.9783 - val_loss: 0.0799 - val_acc: 0.9781
#
# Epoch 00063: val_acc did not improve from 0.97838
# Epoch 64/100
#  - 24s - loss: 0.0754 - acc: 0.9783 - val_loss: 0.0800 - val_acc: 0.9780
#
# Epoch 00064: val_acc did not improve from 0.97838
# Epoch 65/100
#  - 24s - loss: 0.0754 - acc: 0.9780 - val_loss: 0.0801 - val_acc: 0.9778
#
# Epoch 00065: val_acc did not improve from 0.97838
# Epoch 66/100
#  - 24s - loss: 0.0747 - acc: 0.9786 - val_loss: 0.0796 - val_acc: 0.9785
#
# Epoch 00066: val_acc improved from 0.97838 to 0.97846, saving model to best_model_Ass11.h5
# Epoch 67/100
#  - 24s - loss: 0.0752 - acc: 0.9782 - val_loss: 0.0799 - val_acc: 0.9781
#
# Epoch 00067: val_acc did not improve from 0.97846
# Epoch 68/100
#  - 24s - loss: 0.0748 - acc: 0.9781 - val_loss: 0.0794 - val_acc: 0.9784
#
# Epoch 00068: val_acc did not improve from 0.97846
# Epoch 69/100
#  - 24s - loss: 0.0738 - acc: 0.9788 - val_loss: 0.0794 - val_acc: 0.9784
#
# Epoch 00069: val_acc did not improve from 0.97846
# Epoch 70/100
#  - 24s - loss: 0.0735 - acc: 0.9787 - val_loss: 0.0792 - val_acc: 0.9782
#
# Epoch 00070: val_acc did not improve from 0.97846
# Epoch 71/100
#  - 23s - loss: 0.0733 - acc: 0.9788 - val_loss: 0.0791 - val_acc: 0.9782
#
# Epoch 00071: val_acc did not improve from 0.97846
# Epoch 72/100
#  - 24s - loss: 0.0731 - acc: 0.9789 - val_loss: 0.0788 - val_acc: 0.9784
#
# Epoch 00072: val_acc did not improve from 0.97846
# Epoch 73/100
#  - 24s - loss: 0.0734 - acc: 0.9789 - val_loss: 0.0792 - val_acc: 0.9780
#
# Epoch 00073: val_acc did not improve from 0.97846
# Epoch 74/100
#  - 23s - loss: 0.0732 - acc: 0.9789 - val_loss: 0.0787 - val_acc: 0.9785
#
# Epoch 00074: val_acc improved from 0.97846 to 0.97849, saving model to best_model_Ass11.h5
# Epoch 75/100
#  - 23s - loss: 0.0728 - acc: 0.9790 - val_loss: 0.0790 - val_acc: 0.9782
#
# Epoch 00075: val_acc did not improve from 0.97849
# Epoch 76/100
#  - 23s - loss: 0.0734 - acc: 0.9790 - val_loss: 0.0798 - val_acc: 0.9782
#
# Epoch 00076: val_acc did not improve from 0.97849
# Epoch 77/100
#  - 24s - loss: 0.0732 - acc: 0.9788 - val_loss: 0.0791 - val_acc: 0.9784
#
# Epoch 00077: val_acc did not improve from 0.97849
# Epoch 78/100
#  - 24s - loss: 0.0724 - acc: 0.9792 - val_loss: 0.0790 - val_acc: 0.9784
#
# Epoch 00078: val_acc did not improve from 0.97849
# Epoch 79/100
#  - 23s - loss: 0.0723 - acc: 0.9793 - val_loss: 0.0789 - val_acc: 0.9781
#
# Epoch 00079: val_acc did not improve from 0.97849
# Epoch 80/100
#  - 24s - loss: 0.0717 - acc: 0.9796 - val_loss: 0.0785 - val_acc: 0.9785
#
# Epoch 00080: val_acc improved from 0.97849 to 0.97853, saving model to best_model_Ass11.h5
# Epoch 81/100
#  - 24s - loss: 0.0725 - acc: 0.9789 - val_loss: 0.0788 - val_acc: 0.9782
#
# Epoch 00081: val_acc did not improve from 0.97853
# Epoch 82/100
#  - 24s - loss: 0.0722 - acc: 0.9793 - val_loss: 0.0788 - val_acc: 0.9784
#
# Epoch 00082: val_acc did not improve from 0.97853
# Epoch 83/100
#  - 24s - loss: 0.0717 - acc: 0.9795 - val_loss: 0.0790 - val_acc: 0.9784
#
# Epoch 00083: val_acc did not improve from 0.97853
# Epoch 84/100
#  - 23s - loss: 0.0717 - acc: 0.9794 - val_loss: 0.0787 - val_acc: 0.9786
#
# Epoch 00084: val_acc improved from 0.97853 to 0.97857, saving model to best_model_Ass11.h5
# Epoch 85/100
#  - 23s - loss: 0.0719 - acc: 0.9794 - val_loss: 0.0787 - val_acc: 0.9784
#
# Epoch 00085: val_acc did not improve from 0.97857
# Epoch 86/100
#  - 24s - loss: 0.0718 - acc: 0.9795 - val_loss: 0.0784 - val_acc: 0.9786
#
# Epoch 00086: val_acc improved from 0.97857 to 0.97860, saving model to best_model_Ass11.h5
# Epoch 87/100
#  - 23s - loss: 0.0722 - acc: 0.9793 - val_loss: 0.0786 - val_acc: 0.9785
#
# Epoch 00087: val_acc did not improve from 0.97860
# Epoch 88/100
#  - 24s - loss: 0.0723 - acc: 0.9795 - val_loss: 0.0786 - val_acc: 0.9784
#
# Epoch 00088: val_acc did not improve from 0.97860
# Epoch 89/100
#  - 23s - loss: 0.0715 - acc: 0.9798 - val_loss: 0.0785 - val_acc: 0.9787
#
# Epoch 00089: val_acc improved from 0.97860 to 0.97866, saving model to best_model_Ass11.h5
# Epoch 90/100
#  - 23s - loss: 0.0718 - acc: 0.9792 - val_loss: 0.0785 - val_acc: 0.9785
#
# Epoch 00090: val_acc did not improve from 0.97866
# Epoch 91/100
#  - 23s - loss: 0.0716 - acc: 0.9795 - val_loss: 0.0784 - val_acc: 0.9786
#
# Epoch 00091: val_acc did not improve from 0.97866
# Epoch 92/100
#  - 24s - loss: 0.0720 - acc: 0.9793 - val_loss: 0.0784 - val_acc: 0.9786
#
# Epoch 00092: val_acc did not improve from 0.97866
# Epoch 93/100
#  - 23s - loss: 0.0718 - acc: 0.9796 - val_loss: 0.0785 - val_acc: 0.9785
#
# Epoch 00093: val_acc did not improve from 0.97866
# Epoch 94/100
#  - 24s - loss: 0.0716 - acc: 0.9796 - val_loss: 0.0784 - val_acc: 0.9786
#
# Epoch 00094: val_acc did not improve from 0.97866
# Epoch 95/100
#  - 24s - loss: 0.0710 - acc: 0.9798 - val_loss: 0.0784 - val_acc: 0.9785
#
# Epoch 00095: val_acc did not improve from 0.97866
# Epoch 96/100
#  - 24s - loss: 0.0703 - acc: 0.9801 - val_loss: 0.0784 - val_acc: 0.9785
#
# Epoch 00096: val_acc did not improve from 0.97866
# Epoch 97/100
#  - 24s - loss: 0.0711 - acc: 0.9795 - val_loss: 0.0784 - val_acc: 0.9784
#
# Epoch 00097: val_acc did not improve from 0.97866
# Epoch 98/100
#  - 24s - loss: 0.0713 - acc: 0.9795 - val_loss: 0.0785 - val_acc: 0.9785
#
# Epoch 00098: val_acc did not improve from 0.97866
# Epoch 99/100
#  - 24s - loss: 0.0715 - acc: 0.9796 - val_loss: 0.0783 - val_acc: 0.9786
#
# Epoch 00099: val_acc did not improve from 0.97866
# Epoch 100/100
#  - 24s - loss: 0.0710 - acc: 0.9797 - val_loss: 0.0783 - val_acc: 0.9786
#
# Epoch 00100: val_acc did not improve from 0.97866
# Model took 2365.49 seconds to train

# %% [markdown]
# # # 10. Run LR Finder to get the best LR

# %%
lrf = LRFinder(model)

generator = datagen.flow(train_features, train_labels, batch_size=batch_size, shuffle=True)                             
test_generator = datagen_validation.flow(test_features, test_labels, batch_size=batch_size, shuffle=True)

lrf.find_generator(generator, 0.0001, 10.0, test_generator, epochs=1, steps_per_epoch=None,)
lrf.plot_loss()
# Out:
# Stop Training at 244, loss = 0.570

# %% [markdown]
# # # 10. Run OneCycleLR with the initial LR rate equal to best LR found

# %%
# reset the model weights
model1 = build_model()
train_history = train_network(model1, epochs=100, one_cycle_start_lr=0.044)
# Out:
# Epoch 1/100
#  - 26s - loss: 0.3174 - acc: 0.9007 - val_loss: 0.2706 - val_acc: 0.9106
#
# Epoch 00001: val_acc improved from -inf to 0.91058, saving model to best_model_Ass11.h5
#  - lr: 0.00528 - momentum: 0.95
# Epoch 2/100
#  - 25s - loss: 0.2762 - acc: 0.9092 - val_loss: 0.2520 - val_acc: 0.9174
#
# Epoch 00002: val_acc improved from 0.91058 to 0.91739, saving model to best_model_Ass11.h5
#  - lr: 0.00616 - momentum: 0.95
# Epoch 3/100
#  - 25s - loss: 0.2577 - acc: 0.9146 - val_loss: 0.2299 - val_acc: 0.9249
#
# Epoch 00003: val_acc improved from 0.91739 to 0.92486, saving model to best_model_Ass11.h5
#  - lr: 0.00704 - momentum: 0.94
# Epoch 4/100
#  - 25s - loss: 0.2434 - acc: 0.9196 - val_loss: 0.2229 - val_acc: 0.9267
#
# Epoch 00004: val_acc improved from 0.92486 to 0.92671, saving model to best_model_Ass11.h5
#  - lr: 0.00792 - momentum: 0.94
# Epoch 5/100
#  - 25s - loss: 0.2306 - acc: 0.9244 - val_loss: 0.2025 - val_acc: 0.9355
#
# Epoch 00005: val_acc improved from 0.92671 to 0.93554, saving model to best_model_Ass11.h5
#  - lr: 0.00880 - momentum: 0.94
# Epoch 6/100
#  - 25s - loss: 0.2222 - acc: 0.9271 - val_loss: 0.1995 - val_acc: 0.9367
#
# Epoch 00006: val_acc improved from 0.93554 to 0.93672, saving model to best_model_Ass11.h5
#  - lr: 0.00968 - momentum: 0.94
# Epoch 7/100
#  - 25s - loss: 0.2139 - acc: 0.9304 - val_loss: 0.1954 - val_acc: 0.9377
#
# Epoch 00007: val_acc improved from 0.93672 to 0.93766, saving model to best_model_Ass11.h5
#  - lr: 0.01056 - momentum: 0.93
# Epoch 8/100
#  - 25s - loss: 0.2067 - acc: 0.9329 - val_loss: 0.1838 - val_acc: 0.9423
#
# Epoch 00008: val_acc improved from 0.93766 to 0.94231, saving model to best_model_Ass11.h5
#  - lr: 0.01144 - momentum: 0.93
# Epoch 9/100
#  - 25s - loss: 0.1999 - acc: 0.9350 - val_loss: 0.1814 - val_acc: 0.9415
#
# Epoch 00009: val_acc did not improve from 0.94231
#  - lr: 0.01232 - momentum: 0.93
# Epoch 10/100
#  - 25s - loss: 0.1952 - acc: 0.9362 - val_loss: 0.1690 - val_acc: 0.9462
#
# Epoch 00010: val_acc improved from 0.94231 to 0.94623, saving model to best_model_Ass11.h5
#  - lr: 0.01320 - momentum: 0.93
# Epoch 11/100
#  - 25s - loss: 0.1900 - acc: 0.9385 - val_loss: 0.1719 - val_acc: 0.9449
#
# Epoch 00011: val_acc did not improve from 0.94623
#  - lr: 0.01408 - momentum: 0.93
# Epoch 12/100
#  - 25s - loss: 0.1858 - acc: 0.9397 - val_loss: 0.1591 - val_acc: 0.9506
#
# Epoch 00012: val_acc improved from 0.94623 to 0.95060, saving model to best_model_Ass11.h5
#  - lr: 0.01496 - momentum: 0.92
# Epoch 13/100
#  - 25s - loss: 0.1816 - acc: 0.9413 - val_loss: 0.1597 - val_acc: 0.9498
#
# Epoch 00013: val_acc did not improve from 0.95060
#  - lr: 0.01584 - momentum: 0.92
# Epoch 14/100
#  - 25s - loss: 0.1761 - acc: 0.9433 - val_loss: 0.1536 - val_acc: 0.9523
#
# Epoch 00014: val_acc improved from 0.95060 to 0.95228, saving model to best_model_Ass11.h5
#  - lr: 0.01672 - momentum: 0.92
# Epoch 15/100
#  - 25s - loss: 0.1721 - acc: 0.9444 - val_loss: 0.1468 - val_acc: 0.9547
#
# Epoch 00015: val_acc improved from 0.95228 to 0.95468, saving model to best_model_Ass11.h5
#  - lr: 0.01760 - momentum: 0.92
# Epoch 16/100
#  - 25s - loss: 0.1675 - acc: 0.9460 - val_loss: 0.1396 - val_acc: 0.9573
#
# Epoch 00016: val_acc improved from 0.95468 to 0.95728, saving model to best_model_Ass11.h5
#  - lr: 0.01848 - momentum: 0.91
# Epoch 17/100
#  - 25s - loss: 0.1656 - acc: 0.9470 - val_loss: 0.1375 - val_acc: 0.9577
#
# Epoch 00017: val_acc improved from 0.95728 to 0.95773, saving model to best_model_Ass11.h5
#  - lr: 0.01936 - momentum: 0.91
# Epoch 18/100
#  - 25s - loss: 0.1607 - acc: 0.9483 - val_loss: 0.1382 - val_acc: 0.9576
#
# Epoch 00018: val_acc did not improve from 0.95773
#  - lr: 0.02024 - momentum: 0.91
# Epoch 19/100
#  - 25s - loss: 0.1575 - acc: 0.9494 - val_loss: 0.1338 - val_acc: 0.9591
#
# Epoch 00019: val_acc improved from 0.95773 to 0.95905, saving model to best_model_Ass11.h5
#  - lr: 0.02112 - momentum: 0.91
# Epoch 20/100
#  - 25s - loss: 0.1547 - acc: 0.9505 - val_loss: 0.1339 - val_acc: 0.9596
#
# Epoch 00020: val_acc improved from 0.95905 to 0.95961, saving model to best_model_Ass11.h5
#  - lr: 0.02200 - momentum: 0.91
# Epoch 21/100
#  - 25s - loss: 0.1525 - acc: 0.9510 - val_loss: 0.1242 - val_acc: 0.9626
#
# Epoch 00021: val_acc improved from 0.95961 to 0.96257, saving model to best_model_Ass11.h5
#  - lr: 0.02288 - momentum: 0.90
# Epoch 22/100
#  - 25s - loss: 0.1496 - acc: 0.9523 - val_loss: 0.1282 - val_acc: 0.9612
#
# Epoch 00022: val_acc did not improve from 0.96257
#  - lr: 0.02376 - momentum: 0.90
# Epoch 23/100
#  - 25s - loss: 0.1471 - acc: 0.9528 - val_loss: 0.1241 - val_acc: 0.9629
#
# Epoch 00023: val_acc improved from 0.96257 to 0.96292, saving model to best_model_Ass11.h5
#  - lr: 0.02464 - momentum: 0.90
# Epoch 24/100
#  - 25s - loss: 0.1455 - acc: 0.9538 - val_loss: 0.1222 - val_acc: 0.9635
#
# Epoch 00024: val_acc improved from 0.96292 to 0.96345, saving model to best_model_Ass11.h5
#  - lr: 0.02552 - momentum: 0.90
# Epoch 25/100
#  - 25s - loss: 0.1427 - acc: 0.9547 - val_loss: 0.1302 - val_acc: 0.9591
#
# Epoch 00025: val_acc did not improve from 0.96345
#  - lr: 0.02640 - momentum: 0.89
# Epoch 26/100
#  - 25s - loss: 0.1408 - acc: 0.9550 - val_loss: 0.1180 - val_acc: 0.9646
#
# Epoch 00026: val_acc improved from 0.96345 to 0.96456, saving model to best_model_Ass11.h5
#  - lr: 0.02728 - momentum: 0.89
# Epoch 27/100
#  - 25s - loss: 0.1384 - acc: 0.9559 - val_loss: 0.1128 - val_acc: 0.9664
#
# Epoch 00027: val_acc improved from 0.96456 to 0.96637, saving model to best_model_Ass11.h5
#  - lr: 0.02816 - momentum: 0.89
# Epoch 28/100
#  - 25s - loss: 0.1365 - acc: 0.9564 - val_loss: 0.1223 - val_acc: 0.9638
#
# Epoch 00028: val_acc did not improve from 0.96637
#  - lr: 0.02904 - momentum: 0.89
# Epoch 29/100
#  - 25s - loss: 0.1342 - acc: 0.9571 - val_loss: 0.1194 - val_acc: 0.9637
#
# Epoch 00029: val_acc did not improve from 0.96637
#  - lr: 0.02992 - momentum: 0.89
# Epoch 30/100
#  - 25s - loss: 0.1331 - acc: 0.9576 - val_loss: 0.1166 - val_acc: 0.9655
#
# Epoch 00030: val_acc did not improve from 0.96637
#  - lr: 0.03080 - momentum: 0.88
# Epoch 31/100
#  - 25s - loss: 0.1310 - acc: 0.9582 - val_loss: 0.1174 - val_acc: 0.9656
#
# Epoch 00031: val_acc did not improve from 0.96637
#  - lr: 0.03168 - momentum: 0.88
# Epoch 32/100
#  - 25s - loss: 0.1298 - acc: 0.9587 - val_loss: 0.1091 - val_acc: 0.9676
#
# Epoch 00032: val_acc improved from 0.96637 to 0.96757, saving model to best_model_Ass11.h5
#  - lr: 0.03256 - momentum: 0.88
# Epoch 33/100
#  - 25s - loss: 0.1281 - acc: 0.9596 - val_loss: 0.1115 - val_acc: 0.9665
#
# Epoch 00033: val_acc did not improve from 0.96757
#  - lr: 0.03344 - momentum: 0.88
# Epoch 34/100
#  - 25s - loss: 0.1268 - acc: 0.9598 - val_loss: 0.1129 - val_acc: 0.9667
#
# Epoch 00034: val_acc did not improve from 0.96757
#  - lr: 0.03432 - momentum: 0.87
# Epoch 35/100
#  - 25s - loss: 0.1254 - acc: 0.9603 - val_loss: 0.1074 - val_acc: 0.9683
#
# Epoch 00035: val_acc improved from 0.96757 to 0.96830, saving model to best_model_Ass11.h5
#  - lr: 0.03520 - momentum: 0.87
# Epoch 36/100
#  - 25s - loss: 0.1238 - acc: 0.9609 - val_loss: 0.1098 - val_acc: 0.9673
#
# Epoch 00036: val_acc did not improve from 0.96830
#  - lr: 0.03608 - momentum: 0.87
# Epoch 37/100
#  - 25s - loss: 0.1235 - acc: 0.9607 - val_loss: 0.1038 - val_acc: 0.9703
#
# Epoch 00037: val_acc improved from 0.96830 to 0.97033, saving model to best_model_Ass11.h5
#  - lr: 0.03696 - momentum: 0.87
# Epoch 38/100
#  - 25s - loss: 0.1216 - acc: 0.9617 - val_loss: 0.1050 - val_acc: 0.9689
#
# Epoch 00038: val_acc did not improve from 0.97033
#  - lr: 0.03784 - momentum: 0.87
# Epoch 39/100
#  - 25s - loss: 0.1209 - acc: 0.9620 - val_loss: 0.1030 - val_acc: 0.9700
#
# Epoch 00039: val_acc did not improve from 0.97033
#  - lr: 0.03872 - momentum: 0.86
# Epoch 40/100
#  - 25s - loss: 0.1192 - acc: 0.9626 - val_loss: 0.1089 - val_acc: 0.9675
#
# Epoch 00040: val_acc did not improve from 0.97033
#  - lr: 0.03960 - momentum: 0.86
# Epoch 41/100
#  - 25s - loss: 0.1179 - acc: 0.9632 - val_loss: 0.1051 - val_acc: 0.9695
#
# Epoch 00041: val_acc did not improve from 0.97033
#  - lr: 0.04048 - momentum: 0.86
# Epoch 42/100
#  - 25s - loss: 0.1180 - acc: 0.9631 - val_loss: 0.1008 - val_acc: 0.9705
#
# Epoch 00042: val_acc improved from 0.97033 to 0.97048, saving model to best_model_Ass11.h5
#  - lr: 0.04136 - momentum: 0.86
# Epoch 43/100
#  - 25s - loss: 0.1162 - acc: 0.9636 - val_loss: 0.1054 - val_acc: 0.9700
#
# Epoch 00043: val_acc did not improve from 0.97048
#  - lr: 0.04224 - momentum: 0.85
# Epoch 44/100
#  - 25s - loss: 0.1163 - acc: 0.9637 - val_loss: 0.1091 - val_acc: 0.9682
#
# Epoch 00044: val_acc did not improve from 0.97048
#  - lr: 0.04312 - momentum: 0.85
# Epoch 45/100
#  - 25s - loss: 0.1160 - acc: 0.9641 - val_loss: 0.1074 - val_acc: 0.9687
#
# Epoch 00045: val_acc did not improve from 0.97048
#  - lr: 0.04400 - momentum: 0.85
# Epoch 46/100
#  - 25s - loss: 0.1139 - acc: 0.9649 - val_loss: 0.1003 - val_acc: 0.9704
#
# Epoch 00046: val_acc did not improve from 0.97048
#  - lr: 0.04312 - momentum: 0.85
# Epoch 47/100
#  - 25s - loss: 0.1130 - acc: 0.9650 - val_loss: 0.0984 - val_acc: 0.9722
#
# Epoch 00047: val_acc improved from 0.97048 to 0.97221, saving model to best_model_Ass11.h5
#  - lr: 0.04224 - momentum: 0.85
# Epoch 48/100
#  - 25s - loss: 0.1129 - acc: 0.9652 - val_loss: 0.0978 - val_acc: 0.9718
#
# Epoch 00048: val_acc did not improve from 0.97221
#  - lr: 0.04136 - momentum: 0.86
# Epoch 49/100
#  - 25s - loss: 0.1122 - acc: 0.9653 - val_loss: 0.1030 - val_acc: 0.9701
#
# Epoch 00049: val_acc did not improve from 0.97221
#  - lr: 0.04048 - momentum: 0.86
# Epoch 50/100
#  - 25s - loss: 0.1108 - acc: 0.9664 - val_loss: 0.0988 - val_acc: 0.9724
#
# Epoch 00050: val_acc improved from 0.97221 to 0.97239, saving model to best_model_Ass11.h5
#  - lr: 0.03960 - momentum: 0.86
# Epoch 51/100
#  - 25s - loss: 0.1106 - acc: 0.9660 - val_loss: 0.1002 - val_acc: 0.9717
#
# Epoch 00051: val_acc did not improve from 0.97239
#  - lr: 0.03872 - momentum: 0.86
# Epoch 52/100
#  - 25s - loss: 0.1092 - acc: 0.9668 - val_loss: 0.0994 - val_acc: 0.9718
#
# Epoch 00052: val_acc did not improve from 0.97239
#  - lr: 0.03784 - momentum: 0.87
# Epoch 53/100
#  - 25s - loss: 0.1096 - acc: 0.9664 - val_loss: 0.0965 - val_acc: 0.9731
#
# Epoch 00053: val_acc improved from 0.97239 to 0.97305, saving model to best_model_Ass11.h5
#  - lr: 0.03696 - momentum: 0.87
# Epoch 54/100
#  - 25s - loss: 0.1081 - acc: 0.9673 - val_loss: 0.1007 - val_acc: 0.9710
#
# Epoch 00054: val_acc did not improve from 0.97305
#  - lr: 0.03608 - momentum: 0.87
# Epoch 55/100
#  - 25s - loss: 0.1078 - acc: 0.9674 - val_loss: 0.0980 - val_acc: 0.9729
#
# Epoch 00055: val_acc did not improve from 0.97305
#  - lr: 0.03520 - momentum: 0.87
# Epoch 56/100
#  - 25s - loss: 0.1071 - acc: 0.9676 - val_loss: 0.0972 - val_acc: 0.9736
#
# Epoch 00056: val_acc improved from 0.97305 to 0.97356, saving model to best_model_Ass11.h5
#  - lr: 0.03432 - momentum: 0.87
# Epoch 57/100
#  - 25s - loss: 0.1059 - acc: 0.9681 - val_loss: 0.0981 - val_acc: 0.9726
#
# Epoch 00057: val_acc did not improve from 0.97356
#  - lr: 0.03344 - momentum: 0.88
# Epoch 58/100
#  - 25s - loss: 0.1055 - acc: 0.9680 - val_loss: 0.0976 - val_acc: 0.9727
#
# Epoch 00058: val_acc did not improve from 0.97356
#  - lr: 0.03256 - momentum: 0.88
# Epoch 59/100
#  - 25s - loss: 0.1046 - acc: 0.9686 - val_loss: 0.1021 - val_acc: 0.9711
#
# Epoch 00059: val_acc did not improve from 0.97356
#  - lr: 0.03168 - momentum: 0.88
# Epoch 60/100
#  - 25s - loss: 0.1051 - acc: 0.9680 - val_loss: 0.1024 - val_acc: 0.9714
#
# Epoch 00060: val_acc did not improve from 0.97356
#  - lr: 0.03080 - momentum: 0.88
# Epoch 61/100
#  - 25s - loss: 0.1044 - acc: 0.9690 - val_loss: 0.1005 - val_acc: 0.9718
#
# Epoch 00061: val_acc did not improve from 0.97356
#  - lr: 0.02992 - momentum: 0.89
# Epoch 62/100
#  - 25s - loss: 0.1040 - acc: 0.9690 - val_loss: 0.0950 - val_acc: 0.9738
#
# Epoch 00062: val_acc improved from 0.97356 to 0.97383, saving model to best_model_Ass11.h5
#  - lr: 0.02904 - momentum: 0.89
# Epoch 63/100
#  - 25s - loss: 0.1024 - acc: 0.9696 - val_loss: 0.0965 - val_acc: 0.9730
#
# Epoch 00063: val_acc did not improve from 0.97383
#  - lr: 0.02816 - momentum: 0.89
# Epoch 64/100
#  - 25s - loss: 0.1024 - acc: 0.9693 - val_loss: 0.0954 - val_acc: 0.9742
#
# Epoch 00064: val_acc improved from 0.97383 to 0.97419, saving model to best_model_Ass11.h5
#  - lr: 0.02728 - momentum: 0.89
# Epoch 65/100
#  - 25s - loss: 0.1022 - acc: 0.9697 - val_loss: 0.1003 - val_acc: 0.9718
#
# Epoch 00065: val_acc did not improve from 0.97419
#  - lr: 0.02640 - momentum: 0.89
# Epoch 66/100
#  - 25s - loss: 0.1001 - acc: 0.9705 - val_loss: 0.0964 - val_acc: 0.9731
#
# Epoch 00066: val_acc did not improve from 0.97419
#  - lr: 0.02552 - momentum: 0.90
# Epoch 67/100
#  - 25s - loss: 0.1005 - acc: 0.9700 - val_loss: 0.0969 - val_acc: 0.9733
#
# Epoch 00067: val_acc did not improve from 0.97419
#  - lr: 0.02464 - momentum: 0.90
# Epoch 68/100
#  - 25s - loss: 0.1002 - acc: 0.9705 - val_loss: 0.0961 - val_acc: 0.9736
#
# Epoch 00068: val_acc did not improve from 0.97419
#  - lr: 0.02376 - momentum: 0.90
# Epoch 69/100
#  - 25s - loss: 0.0985 - acc: 0.9713 - val_loss: 0.0934 - val_acc: 0.9752
#
# Epoch 00069: val_acc improved from 0.97419 to 0.97520, saving model to best_model_Ass11.h5
#  - lr: 0.02288 - momentum: 0.90
# Epoch 70/100
#  - 25s - loss: 0.0983 - acc: 0.9714 - val_loss: 0.0985 - val_acc: 0.9734
#
# Epoch 00070: val_acc did not improve from 0.97520
#  - lr: 0.02200 - momentum: 0.91
# Epoch 71/100
#  - 25s - loss: 0.0973 - acc: 0.9716 - val_loss: 0.0942 - val_acc: 0.9745
#
# Epoch 00071: val_acc did not improve from 0.97520
#  - lr: 0.02112 - momentum: 0.91
# Epoch 72/100
#  - 25s - loss: 0.0975 - acc: 0.9715 - val_loss: 0.0935 - val_acc: 0.9751
#
# Epoch 00072: val_acc did not improve from 0.97520
#  - lr: 0.02024 - momentum: 0.91
# Epoch 73/100
#  - 25s - loss: 0.0972 - acc: 0.9716 - val_loss: 0.0945 - val_acc: 0.9745
#
# Epoch 00073: val_acc did not improve from 0.97520
#  - lr: 0.01936 - momentum: 0.91
# Epoch 74/100
#  - 25s - loss: 0.0967 - acc: 0.9719 - val_loss: 0.0933 - val_acc: 0.9750
#
# Epoch 00074: val_acc did not improve from 0.97520
#  - lr: 0.01848 - momentum: 0.91
# Epoch 75/100
#  - 25s - loss: 0.0946 - acc: 0.9727 - val_loss: 0.0940 - val_acc: 0.9751
#
# Epoch 00075: val_acc did not improve from 0.97520
#  - lr: 0.01760 - momentum: 0.92
# Epoch 76/100
#  - 25s - loss: 0.0939 - acc: 0.9729 - val_loss: 0.0968 - val_acc: 0.9747
#
# Epoch 00076: val_acc did not improve from 0.97520
#  - lr: 0.01672 - momentum: 0.92
# Epoch 77/100
#  - 25s - loss: 0.0933 - acc: 0.9729 - val_loss: 0.0926 - val_acc: 0.9755
#
# Epoch 00077: val_acc improved from 0.97520 to 0.97554, saving model to best_model_Ass11.h5
#  - lr: 0.01584 - momentum: 0.92
# Epoch 78/100
#  - 25s - loss: 0.0936 - acc: 0.9731 - val_loss: 0.0936 - val_acc: 0.9758
#
# Epoch 00078: val_acc improved from 0.97554 to 0.97575, saving model to best_model_Ass11.h5
#  - lr: 0.01496 - momentum: 0.92
# Epoch 79/100
#  - 25s - loss: 0.0922 - acc: 0.9735 - val_loss: 0.0944 - val_acc: 0.9748
#
# Epoch 00079: val_acc did not improve from 0.97575
#  - lr: 0.01408 - momentum: 0.93
# Epoch 80/100
#  - 25s - loss: 0.0921 - acc: 0.9738 - val_loss: 0.0889 - val_acc: 0.9770
#
# Epoch 00080: val_acc improved from 0.97575 to 0.97701, saving model to best_model_Ass11.h5
#  - lr: 0.01320 - momentum: 0.93
# Epoch 81/100
#  - 25s - loss: 0.0894 - acc: 0.9748 - val_loss: 0.0908 - val_acc: 0.9764
#
# Epoch 00081: val_acc did not improve from 0.97701
#  - lr: 0.01232 - momentum: 0.93
# Epoch 82/100
#  - 25s - loss: 0.0897 - acc: 0.9745 - val_loss: 0.0907 - val_acc: 0.9768
#
# Epoch 00082: val_acc did not improve from 0.97701
#  - lr: 0.01144 - momentum: 0.93
# Epoch 83/100
#  - 25s - loss: 0.0887 - acc: 0.9748 - val_loss: 0.0897 - val_acc: 0.9769
#
# Epoch 00083: val_acc did not improve from 0.97701
#  - lr: 0.01056 - momentum: 0.93
# Epoch 84/100
#  - 25s - loss: 0.0864 - acc: 0.9759 - val_loss: 0.0908 - val_acc: 0.9757
#
# Epoch 00084: val_acc did not improve from 0.97701
#  - lr: 0.00968 - momentum: 0.94
# Epoch 85/100
#  - 25s - loss: 0.0865 - acc: 0.9757 - val_loss: 0.0903 - val_acc: 0.9764
#
# Epoch 00085: val_acc did not improve from 0.97701
#  - lr: 0.00880 - momentum: 0.94
# Epoch 86/100
#  - 25s - loss: 0.0849 - acc: 0.9761 - val_loss: 0.0915 - val_acc: 0.9760
#
# Epoch 00086: val_acc did not improve from 0.97701
#  - lr: 0.00792 - momentum: 0.94
# Epoch 87/100
#  - 25s - loss: 0.0837 - acc: 0.9767 - val_loss: 0.0865 - val_acc: 0.9777
#
# Epoch 00087: val_acc improved from 0.97701 to 0.97772, saving model to best_model_Ass11.h5
#  - lr: 0.00704 - momentum: 0.94
# Epoch 88/100
#  - 25s - loss: 0.0817 - acc: 0.9773 - val_loss: 0.0874 - val_acc: 0.9772
#
# Epoch 00088: val_acc did not improve from 0.97772
#  - lr: 0.00616 - momentum: 0.95
# Epoch 89/100
#  - 25s - loss: 0.0811 - acc: 0.9775 - val_loss: 0.0849 - val_acc: 0.9780
#
# Epoch 00089: val_acc improved from 0.97772 to 0.97797, saving model to best_model_Ass11.h5
#  - lr: 0.00528 - momentum: 0.95
# Epoch 90/100
#  - 25s - loss: 0.0795 - acc: 0.9782 - val_loss: 0.0858 - val_acc: 0.9775
#
# Epoch 00090: val_acc did not improve from 0.97797
#  - lr: 0.00440 - momentum: 0.95
# Epoch 91/100
#  - 25s - loss: 0.0778 - acc: 0.9785 - val_loss: 0.0847 - val_acc: 0.9788
#
# Epoch 00091: val_acc improved from 0.97797 to 0.97880, saving model to best_model_Ass11.h5
#  - lr: 0.00397 - momentum: 0.95
# Epoch 92/100
#  - 25s - loss: 0.0769 - acc: 0.9791 - val_loss: 0.0836 - val_acc: 0.9785
#
# Epoch 00092: val_acc did not improve from 0.97880
#  - lr: 0.00353 - momentum: 0.95
# Epoch 93/100
#  - 25s - loss: 0.0755 - acc: 0.9798 - val_loss: 0.0833 - val_acc: 0.9784
#
# Epoch 00093: val_acc did not improve from 0.97880
#  - lr: 0.00309 - momentum: 0.95
# Epoch 94/100
#  - 25s - loss: 0.0749 - acc: 0.9797 - val_loss: 0.0824 - val_acc: 0.9792
#
# Epoch 00094: val_acc improved from 0.97880 to 0.97916, saving model to best_model_Ass11.h5
#  - lr: 0.00266 - momentum: 0.95
# Epoch 95/100
#  - 25s - loss: 0.0732 - acc: 0.9807 - val_loss: 0.0817 - val_acc: 0.9790
#
# Epoch 00095: val_acc did not improve from 0.97916
#  - lr: 0.00222 - momentum: 0.95
# Epoch 96/100
#  - 25s - loss: 0.0725 - acc: 0.9806 - val_loss: 0.0805 - val_acc: 0.9796
#
# Epoch 00096: val_acc improved from 0.97916 to 0.97960, saving model to best_model_Ass11.h5
#  - lr: 0.00179 - momentum: 0.95
# Epoch 97/100
#  - 25s - loss: 0.0711 - acc: 0.9814 - val_loss: 0.0810 - val_acc: 0.9797
#
# Epoch 00097: val_acc improved from 0.97960 to 0.97971, saving model to best_model_Ass11.h5
#  - lr: 0.00135 - momentum: 0.95
# Epoch 98/100
#  - 25s - loss: 0.0704 - acc: 0.9815 - val_loss: 0.0812 - val_acc: 0.9794
#
# Epoch 00098: val_acc did not improve from 0.97971
#  - lr: 0.00092 - momentum: 0.95
# Epoch 99/100
#  - 25s - loss: 0.0696 - acc: 0.9819 - val_loss: 0.0800 - val_acc: 0.9798
#
# Epoch 00099: val_acc improved from 0.97971 to 0.97981, saving model to best_model_Ass11.h5
#  - lr: 0.00048 - momentum: 0.95
# Epoch 100/100
#  - 25s - loss: 0.0685 - acc: 0.9821 - val_loss: 0.0798 - val_acc: 0.9800
#
# Epoch 00100: val_acc improved from 0.97981 to 0.98000, saving model to best_model_Ass11.h5
#  - lr: 0.00005 - momentum: 0.95
# Model took 2500.37 seconds to train

# %% [markdown]
# # Summary:
#
# The network was initially trained to run for 100 epochs and validation accuracy of **97.866%** was achieved.
#
# Using LR finder the best learning rate for this network was found to be 0.044. And using this as the starting LR, the newtwork was rerun this time using OneCycleLR and an improved validation accuracy of **98%** was achieved.
#
# Thank you!
