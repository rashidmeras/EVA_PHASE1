# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidmeras/EVA_PHASE1/blob/master/Rerun_of_EVA_S6_Assignment_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EVA (M6) Session6 Assignment 6B (Re-Runs):
#
# Objective:
#
# > Using the network defined in Assignment 6A change the code to include:
#
# > * Normal Convolution
# > * Separable Convolution
# > * Depthwise Convolution
# > * Grouped Convolution (use 3x3, 5x5 only)
# > * Grouped Convolution (use 3x3 only, one with dilation = 1, and another with dilation = 2)
#
# Must use all of the 5 above at least once and train this new model for 50 epochs.

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(900) 
from keras.models import Model, Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D
from keras.layers import Conv2D, Activation, Flatten, Dropout, Input, Lambda, Dense, Add
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils, plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import regularizers
from keras.layers.merge import concatenate
from keras.optimizers import Adam, SGD
from keras.layers.advanced_activations import ReLU

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ##Image Normalization

# %%
batch_size = 128

# standardize images
def prep_standardize(train, test):
	# convert from integers to floats
	train_stan = train.astype('float32')
	test_stan  = test.astype('float32')
	# calculate statistics
	m = train_stan.mean()
	s = train_stan.std()
	# center datasets
	train_stan = (train_stan - m) / s
	test_stan  = (test_stan - m) / s
	# return normalized images
	return train_stan, test_stan

train_features, test_features = prep_standardize(train_features, test_features)

# confirm scale of pixels
print('Train min=%.3f, max=%.3f' % (train_features.min(), train_features.max()))
print('Test min=%.3f, max=%.3f' % (test_features.min(), test_features.max()))
# Out:
# Train min=-1.882, max=2.093
# Test min=-1.882, max=2.093

# %% [markdown]
# ## Functional Network

# %%
# Function for common layer
def add_common_layers(y):
    y = BatchNormalization()(y)
    y = ReLU()(y)  
    y = Dropout(0.1)(y)
    
    return y

def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)  

# Define the network  
img_height = 32
img_width = 32
channel = 3
  
input = Input(shape=(img_height, img_width, channel))

#===> 1) Normal Convolution
x = Conv2D(32, (3,3), use_bias=False, padding='same', name='L1_Norm_Conv')(input)
x = add_common_layers(x)


#===> 2) Spatially Speprable Convolution
x = Conv2D(32, (1, 3), use_bias=False, activation='relu', name='L2Spat_Sep_Conv1')(x)
x = Conv2D(32, (3, 1), use_bias=False, activation='relu', name='L2_Spat_Sep_Conv2')(x)

x = Conv2D(32, (3,3), use_bias=False, name='L3_Norm_Conv')(x)
x = add_common_layers(x)

#===> 3) Depthwise Seperable Convolution
x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='L4_Dep_Sep_Conv')(x)
x = add_common_layers(x)

#skip from here
skip_connection = x

# Max-Pooling layer
x = MaxPooling2D(pool_size=(2, 2))(x)

#===> 4) Grouped Convolution (use 3x3, 5x5 only)
x1 = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block0_GroupConv1')(x)
x1 = add_common_layers(x1)
x2 = Conv2D(64, (5, 5), padding='same', use_bias=False, name='block0_GroupConv2')(x)
x2 = add_common_layers(x2)

skip_connection = Conv2D(64, (3, 3), padding='same', use_bias=False, name='L5_Norm_Conv')(skip_connection)
skip_connection = add_common_layers(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)
  
x = concatenate([x1, x2, skip_connection, x])

#===> 5) Grouped Convolution (use 3x3 only, one with dilation = 1, and another with dilation = 2) 
x1 = Conv2D(64, (3, 3), padding='same', dilation_rate=1, activation='relu', use_bias=False, name='block1_GroupConv1')(x)
x2 = Conv2D(64, (3, 3), padding='same', dilation_rate=2, activation='relu', use_bias=False, name='block1_GroupConv2')(x)
  
x = concatenate([x1, x2, x])

# ===> 6) Final: Flatten, Activation
x = Conv2D(10, (7, 7), use_bias=False, name='L7_Norm_Conv')(x)
x = add_common_layers(x)
x = Conv2D(10, (8, 8), use_bias=False, name='L8_Norm_Conv')(x)

flat_layer = Flatten()(x)
output = Activation('softmax')(flat_layer)

model = Model(inputs=[input], outputs=[output])
model.summary()

# plot model architecture
plot_model(model, show_shapes=True, to_file='Assignment_6B_Network.png')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0616 15:21:12.868812 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0616 15:21:12.903215 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0616 15:21:12.910449 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0616 15:21:12.944332 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0616 15:21:12.946376 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0616 15:21:15.343684 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0616 15:21:15.417045 140362443777920 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0616 15:21:15.724622 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# L1_Norm_Conv (Conv2D)           (None, 32, 32, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         L1_Norm_Conv[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# L2Spat_Sep_Conv1 (Conv2D)       (None, 32, 30, 32)   3072        dropout_1[0][0]
# __________________________________________________________________________________________________
# L2_Spat_Sep_Conv2 (Conv2D)      (None, 30, 30, 32)   3072        L2Spat_Sep_Conv1[0][0]
# __________________________________________________________________________________________________
# L3_Norm_Conv (Conv2D)           (None, 28, 28, 32)   9216        L2_Spat_Sep_Conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 32)   128         L3_Norm_Conv[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 28, 28, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 32)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# L4_Dep_Sep_Conv (SeparableConv2 (None, 28, 28, 128)  4384        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 128)  512         L4_Dep_Sep_Conv[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 28, 28, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 128)  0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 128)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# L5_Norm_Conv (Conv2D)           (None, 28, 28, 64)   73728       dropout_3[0][0]
# __________________________________________________________________________________________________
# block0_GroupConv1 (Conv2D)      (None, 14, 14, 64)   73728       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# block0_GroupConv2 (Conv2D)      (None, 14, 14, 64)   204800      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 64)   256         L5_Norm_Conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         block0_GroupConv1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         block0_GroupConv2[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 28, 28, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 14, 14, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 28, 28, 64)   0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 14, 14, 64)   0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 64)   0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 512)  0           dropout_4[0][0]
#                                                                  dropout_5[0][0]
#                                                                  lambda_1[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# block1_GroupConv1 (Conv2D)      (None, 14, 14, 64)   294912      concatenate_1[0][0]
# __________________________________________________________________________________________________
# block1_GroupConv2 (Conv2D)      (None, 14, 14, 64)   294912      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 640)  0           block1_GroupConv1[0][0]
#                                                                  block1_GroupConv2[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# L7_Norm_Conv (Conv2D)           (None, 8, 8, 10)     313600      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 10)     40          L7_Norm_Conv[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 8, 8, 10)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 10)     0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# L8_Norm_Conv (Conv2D)           (None, 1, 1, 10)     6400        dropout_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           L8_Norm_Conv[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 1,284,264
# Trainable params: 1,283,476
# Non-trainable params: 788
# __________________________________________________________________________________________________

# %% [markdown]
# ##Visualizing the network architecture:

# %%
from IPython.display import Image
Image(retina=True, filename='Assignment_6B_Network.png')

# %% [markdown]
# ## Run 1
# Date: 16/06/2019

# %%
import math
import numpy as np
from keras.optimizers import Adam, SGD
from keras.callbacks import LearningRateScheduler

# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# Define custom loss
def custom_loss(actual,predicted):
    sqr_w = 0
    lamda = 1e-2
    
    for layer in model.layers:
       sqr_w = sqr_w + np.sum(np.sum(np.sum(np.square(layer.get_weights()))))
        
    l2_regularization = (lamda*sqr_w)/2*(batch_size)    
    loss = K.binary_crossentropy(actual,predicted) + l2_regularization
    # Return a function
    return loss

sgd = SGD(lr=0.0, momentum=0.9, decay=0.0, nesterov=False)
  
model.compile(optimizer= sgd,
#               loss = custom_loss,
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

save_mcp = ModelCheckpoint('best_new_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# train the model
start = time.time()

# Train the model
history = model.fit(train_features,       
                    train_labels,
                    batch_size=batch_size,
                    epochs=50,                  
                    validation_data=(test_features, test_labels),
                    callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
                    verbose=1)


end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(history)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# W0616 15:21:16.937282 140362443777920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0616 15:21:16.953626 140362443777920 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 42s 840us/step - loss: 0.2226 - acc: 0.9147 - val_loss: 0.2341 - val_acc: 0.9125
#
# Epoch 00001: val_acc improved from -inf to 0.91248, saving model to best_new_model.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.1663 - acc: 0.9348 - val_loss: 0.1698 - val_acc: 0.9345
#
# Epoch 00002: val_acc improved from 0.91248 to 0.93450, saving model to best_new_model.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 38s 750us/step - loss: 0.1405 - acc: 0.9447 - val_loss: 0.2093 - val_acc: 0.9240
#
# Epoch 00003: val_acc did not improve from 0.93450
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.1268 - acc: 0.9501 - val_loss: 0.1331 - val_acc: 0.9488
#
# Epoch 00004: val_acc improved from 0.93450 to 0.94883, saving model to best_new_model.h5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.1153 - acc: 0.9548 - val_loss: 0.1738 - val_acc: 0.9359
#
# Epoch 00005: val_acc did not improve from 0.94883
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.1061 - acc: 0.9586 - val_loss: 0.1330 - val_acc: 0.9488
#
# Epoch 00006: val_acc did not improve from 0.94883
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0995 - acc: 0.9612 - val_loss: 0.1099 - val_acc: 0.9576
#
# Epoch 00007: val_acc improved from 0.94883 to 0.95757, saving model to best_new_model.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 750us/step - loss: 0.0932 - acc: 0.9640 - val_loss: 0.1496 - val_acc: 0.9458
#
# Epoch 00008: val_acc did not improve from 0.95757
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0865 - acc: 0.9665 - val_loss: 0.1213 - val_acc: 0.9550
#
# Epoch 00009: val_acc did not improve from 0.95757
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0702 - acc: 0.9729 - val_loss: 0.1077 - val_acc: 0.9601
#
# Epoch 00010: val_acc improved from 0.95757 to 0.96015, saving model to best_new_model.h5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0646 - acc: 0.9754 - val_loss: 0.1057 - val_acc: 0.9619
#
# Epoch 00011: val_acc improved from 0.96015 to 0.96191, saving model to best_new_model.h5
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0607 - acc: 0.9770 - val_loss: 0.1191 - val_acc: 0.9584
#
# Epoch 00012: val_acc did not improve from 0.96191
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0580 - acc: 0.9780 - val_loss: 0.1047 - val_acc: 0.9620
#
# Epoch 00013: val_acc improved from 0.96191 to 0.96199, saving model to best_new_model.h5
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0543 - acc: 0.9795 - val_loss: 0.1186 - val_acc: 0.9581
#
# Epoch 00014: val_acc did not improve from 0.96199
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0514 - acc: 0.9805 - val_loss: 0.1113 - val_acc: 0.9614
#
# Epoch 00015: val_acc did not improve from 0.96199
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0485 - acc: 0.9814 - val_loss: 0.1201 - val_acc: 0.9593
#
# Epoch 00016: val_acc did not improve from 0.96199
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0459 - acc: 0.9827 - val_loss: 0.1141 - val_acc: 0.9607
#
# Epoch 00017: val_acc did not improve from 0.96199
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0429 - acc: 0.9837 - val_loss: 0.1353 - val_acc: 0.9578
#
# Epoch 00018: val_acc did not improve from 0.96199
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0401 - acc: 0.9849 - val_loss: 0.1129 - val_acc: 0.9626
#
# Epoch 00019: val_acc improved from 0.96199 to 0.96259, saving model to best_new_model.h5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0283 - acc: 0.9897 - val_loss: 0.1059 - val_acc: 0.9658
#
# Epoch 00020: val_acc improved from 0.96259 to 0.96581, saving model to best_new_model.h5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0252 - acc: 0.9908 - val_loss: 0.1143 - val_acc: 0.9638
#
# Epoch 00021: val_acc did not improve from 0.96581
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0232 - acc: 0.9916 - val_loss: 0.1216 - val_acc: 0.9627
#
# Epoch 00022: val_acc did not improve from 0.96581
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 750us/step - loss: 0.0223 - acc: 0.9919 - val_loss: 0.1249 - val_acc: 0.9630
#
# Epoch 00023: val_acc did not improve from 0.96581
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0202 - acc: 0.9927 - val_loss: 0.1452 - val_acc: 0.9596
#
# Epoch 00024: val_acc did not improve from 0.96581
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0198 - acc: 0.9930 - val_loss: 0.1317 - val_acc: 0.9626
#
# Epoch 00025: val_acc did not improve from 0.96581
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0188 - acc: 0.9932 - val_loss: 0.1159 - val_acc: 0.9660
#
# Epoch 00026: val_acc improved from 0.96581 to 0.96602, saving model to best_new_model.h5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0182 - acc: 0.9935 - val_loss: 0.1432 - val_acc: 0.9622
#
# Epoch 00027: val_acc did not improve from 0.96602
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0173 - acc: 0.9937 - val_loss: 0.1264 - val_acc: 0.9637
#
# Epoch 00028: val_acc did not improve from 0.96602
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0163 - acc: 0.9941 - val_loss: 0.1613 - val_acc: 0.9579
#
# Epoch 00029: val_acc did not improve from 0.96602
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0113 - acc: 0.9961 - val_loss: 0.1205 - val_acc: 0.9663
#
# Epoch 00030: val_acc improved from 0.96602 to 0.96631, saving model to best_new_model.h5
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0101 - acc: 0.9966 - val_loss: 0.1261 - val_acc: 0.9658
#
# Epoch 00031: val_acc did not improve from 0.96631
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0089 - acc: 0.9971 - val_loss: 0.1225 - val_acc: 0.9669
#
# Epoch 00032: val_acc improved from 0.96631 to 0.96687, saving model to best_new_model.h5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0087 - acc: 0.9971 - val_loss: 0.1296 - val_acc: 0.9666
#
# Epoch 00033: val_acc did not improve from 0.96687
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0081 - acc: 0.9973 - val_loss: 0.1295 - val_acc: 0.9657
#
# Epoch 00034: val_acc did not improve from 0.96687
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0078 - acc: 0.9974 - val_loss: 0.1324 - val_acc: 0.9651
#
# Epoch 00035: val_acc did not improve from 0.96687
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0076 - acc: 0.9975 - val_loss: 0.1283 - val_acc: 0.9672
#
# Epoch 00036: val_acc improved from 0.96687 to 0.96722, saving model to best_new_model.h5
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0078 - acc: 0.9973 - val_loss: 0.1341 - val_acc: 0.9662
#
# Epoch 00037: val_acc did not improve from 0.96722
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0069 - acc: 0.9977 - val_loss: 0.1265 - val_acc: 0.9676
#
# Epoch 00038: val_acc improved from 0.96722 to 0.96763, saving model to best_new_model.h5
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0068 - acc: 0.9977 - val_loss: 0.1384 - val_acc: 0.9662
#
# Epoch 00039: val_acc did not improve from 0.96763
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0055 - acc: 0.9983 - val_loss: 0.1320 - val_acc: 0.9670
#
# Epoch 00040: val_acc did not improve from 0.96763
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0052 - acc: 0.9984 - val_loss: 0.1335 - val_acc: 0.9670
#
# Epoch 00041: val_acc did not improve from 0.96763
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0049 - acc: 0.9984 - val_loss: 0.1348 - val_acc: 0.9671
#
# Epoch 00042: val_acc did not improve from 0.96763
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0049 - acc: 0.9985 - val_loss: 0.1355 - val_acc: 0.9674
#
# Epoch 00043: val_acc did not improve from 0.96763
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0048 - acc: 0.9985 - val_loss: 0.1326 - val_acc: 0.9674
#
# Epoch 00044: val_acc did not improve from 0.96763
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0044 - acc: 0.9987 - val_loss: 0.1387 - val_acc: 0.9662
#
# Epoch 00045: val_acc did not improve from 0.96763
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 750us/step - loss: 0.0045 - acc: 0.9986 - val_loss: 0.1350 - val_acc: 0.9674
#
# Epoch 00046: val_acc did not improve from 0.96763
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0041 - acc: 0.9988 - val_loss: 0.1359 - val_acc: 0.9669
#
# Epoch 00047: val_acc did not improve from 0.96763
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0041 - acc: 0.9988 - val_loss: 0.1384 - val_acc: 0.9670
#
# Epoch 00048: val_acc did not improve from 0.96763
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0043 - acc: 0.9986 - val_loss: 0.1363 - val_acc: 0.9671
#
# Epoch 00049: val_acc did not improve from 0.96763
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.003125.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0039 - acc: 0.9988 - val_loss: 0.1357 - val_acc: 0.9677
#
# Epoch 00050: val_acc improved from 0.96763 to 0.96773, saving model to best_new_model.h5
# Model took 1876.67 seconds to train
# Accuracy on test data is: 83.54

# %% [markdown]
# ## Run2:

# %%
# train the model
start = time.time()

# Train the model
history = model.fit(train_features,       
                    train_labels,
                    batch_size=batch_size,
                    epochs=50,                  
                    validation_data=(test_features, test_labels),
                    callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
                    verbose=1)


end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(history)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))

import datetime
print(datetime.datetime.now())
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 750us/step - loss: 0.0728 - acc: 0.9737 - val_loss: 0.1550 - val_acc: 0.9516
#
# Epoch 00001: val_acc did not improve from 0.96773
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 38s 752us/step - loss: 0.0456 - acc: 0.9823 - val_loss: 0.1561 - val_acc: 0.9517
#
# Epoch 00002: val_acc did not improve from 0.96773
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0409 - acc: 0.9844 - val_loss: 0.1690 - val_acc: 0.9504
#
# Epoch 00003: val_acc did not improve from 0.96773
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 38s 750us/step - loss: 0.0361 - acc: 0.9862 - val_loss: 0.1496 - val_acc: 0.9548
#
# Epoch 00004: val_acc did not improve from 0.96773
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0324 - acc: 0.9878 - val_loss: 0.1277 - val_acc: 0.9584
#
# Epoch 00005: val_acc did not improve from 0.96773
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0310 - acc: 0.9882 - val_loss: 0.1629 - val_acc: 0.9553
#
# Epoch 00006: val_acc did not improve from 0.96773
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0276 - acc: 0.9896 - val_loss: 0.1985 - val_acc: 0.9508
#
# Epoch 00007: val_acc did not improve from 0.96773
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0253 - acc: 0.9904 - val_loss: 0.1734 - val_acc: 0.9517
#
# Epoch 00008: val_acc did not improve from 0.96773
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0244 - acc: 0.9908 - val_loss: 0.1388 - val_acc: 0.9617
#
# Epoch 00009: val_acc did not improve from 0.96773
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0116 - acc: 0.9960 - val_loss: 0.1219 - val_acc: 0.9658
#
# Epoch 00010: val_acc did not improve from 0.96773
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0076 - acc: 0.9974 - val_loss: 0.1272 - val_acc: 0.9665
#
# Epoch 00011: val_acc did not improve from 0.96773
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0067 - acc: 0.9977 - val_loss: 0.1308 - val_acc: 0.9664
#
# Epoch 00012: val_acc did not improve from 0.96773
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0065 - acc: 0.9977 - val_loss: 0.1374 - val_acc: 0.9660
#
# Epoch 00013: val_acc did not improve from 0.96773
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0063 - acc: 0.9978 - val_loss: 0.1390 - val_acc: 0.9671
#
# Epoch 00014: val_acc did not improve from 0.96773
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0058 - acc: 0.9980 - val_loss: 0.1486 - val_acc: 0.9650
#
# Epoch 00015: val_acc did not improve from 0.96773
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 749us/step - loss: 0.0056 - acc: 0.9981 - val_loss: 0.1421 - val_acc: 0.9657
#
# Epoch 00016: val_acc did not improve from 0.96773
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0054 - acc: 0.9982 - val_loss: 0.1663 - val_acc: 0.9639
#
# Epoch 00017: val_acc did not improve from 0.96773
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0054 - acc: 0.9981 - val_loss: 0.1576 - val_acc: 0.9651
#
# Epoch 00018: val_acc did not improve from 0.96773
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0050 - acc: 0.9982 - val_loss: 0.1600 - val_acc: 0.9647
#
# Epoch 00019: val_acc did not improve from 0.96773
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0037 - acc: 0.9988 - val_loss: 0.1418 - val_acc: 0.9682
#
# Epoch 00020: val_acc improved from 0.96773 to 0.96825, saving model to best_new_model.h5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0024 - acc: 0.9993 - val_loss: 0.1449 - val_acc: 0.9674
#
# Epoch 00021: val_acc did not improve from 0.96825
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0024 - acc: 0.9992 - val_loss: 0.1458 - val_acc: 0.9676
#
# Epoch 00022: val_acc did not improve from 0.96825
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.1505 - val_acc: 0.9674
#
# Epoch 00023: val_acc did not improve from 0.96825
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0020 - acc: 0.9994 - val_loss: 0.1486 - val_acc: 0.9680
#
# Epoch 00024: val_acc did not improve from 0.96825
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 748us/step - loss: 0.0020 - acc: 0.9994 - val_loss: 0.1510 - val_acc: 0.9675
#
# Epoch 00025: val_acc did not improve from 0.96825
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0019 - acc: 0.9994 - val_loss: 0.1475 - val_acc: 0.9685
#
# Epoch 00026: val_acc improved from 0.96825 to 0.96845, saving model to best_new_model.h5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0016 - acc: 0.9995 - val_loss: 0.1510 - val_acc: 0.9680
#
# Epoch 00027: val_acc did not improve from 0.96845
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0014 - acc: 0.9996 - val_loss: 0.1502 - val_acc: 0.9683
#
# Epoch 00028: val_acc did not improve from 0.96845
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0014 - acc: 0.9996 - val_loss: 0.1507 - val_acc: 0.9684
#
# Epoch 00029: val_acc did not improve from 0.96845
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0015 - acc: 0.9996 - val_loss: 0.1459 - val_acc: 0.9688
#
# Epoch 00030: val_acc improved from 0.96845 to 0.96884, saving model to best_new_model.h5
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0012 - acc: 0.9997 - val_loss: 0.1482 - val_acc: 0.9686
#
# Epoch 00031: val_acc did not improve from 0.96884
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0011 - acc: 0.9997 - val_loss: 0.1483 - val_acc: 0.9691
#
# Epoch 00032: val_acc improved from 0.96884 to 0.96908, saving model to best_new_model.h5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0011 - acc: 0.9997 - val_loss: 0.1512 - val_acc: 0.9683
#
# Epoch 00033: val_acc did not improve from 0.96908
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0012 - acc: 0.9997 - val_loss: 0.1497 - val_acc: 0.9690
#
# Epoch 00034: val_acc did not improve from 0.96908
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 9.9180e-04 - acc: 0.9998 - val_loss: 0.1496 - val_acc: 0.9687
#
# Epoch 00035: val_acc did not improve from 0.96908
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 745us/step - loss: 0.0010 - acc: 0.9997 - val_loss: 0.1491 - val_acc: 0.9688
#
# Epoch 00036: val_acc did not improve from 0.96908
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 745us/step - loss: 9.6852e-04 - acc: 0.9997 - val_loss: 0.1477 - val_acc: 0.9693
#
# Epoch 00037: val_acc improved from 0.96908 to 0.96929, saving model to best_new_model.h5
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.0010 - acc: 0.9997 - val_loss: 0.1538 - val_acc: 0.9686
#
# Epoch 00038: val_acc did not improve from 0.96929
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 9.7935e-04 - acc: 0.9997 - val_loss: 0.1535 - val_acc: 0.9686
#
# Epoch 00039: val_acc did not improve from 0.96929
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 8.9563e-04 - acc: 0.9997 - val_loss: 0.1515 - val_acc: 0.9690
#
# Epoch 00040: val_acc did not improve from 0.96929
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 8.3635e-04 - acc: 0.9998 - val_loss: 0.1501 - val_acc: 0.9691
#
# Epoch 00041: val_acc did not improve from 0.96929
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 745us/step - loss: 8.4173e-04 - acc: 0.9998 - val_loss: 0.1519 - val_acc: 0.9688
#
# Epoch 00042: val_acc did not improve from 0.96929
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 745us/step - loss: 7.4820e-04 - acc: 0.9998 - val_loss: 0.1515 - val_acc: 0.9693
#
# Epoch 00043: val_acc improved from 0.96929 to 0.96931, saving model to best_new_model.h5
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 745us/step - loss: 8.1748e-04 - acc: 0.9998 - val_loss: 0.1504 - val_acc: 0.9691
#
# Epoch 00044: val_acc did not improve from 0.96931
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 7.3448e-04 - acc: 0.9998 - val_loss: 0.1529 - val_acc: 0.9689
#
# Epoch 00045: val_acc did not improve from 0.96931
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 7.4981e-04 - acc: 0.9998 - val_loss: 0.1519 - val_acc: 0.9694
#
# Epoch 00046: val_acc improved from 0.96931 to 0.96939, saving model to best_new_model.h5
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 7.6954e-04 - acc: 0.9998 - val_loss: 0.1528 - val_acc: 0.9689
#
# Epoch 00047: val_acc did not improve from 0.96939
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 7.7285e-04 - acc: 0.9998 - val_loss: 0.1532 - val_acc: 0.9691
#
# Epoch 00048: val_acc did not improve from 0.96939
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 7.1921e-04 - acc: 0.9998 - val_loss: 0.1537 - val_acc: 0.9689
#
# Epoch 00049: val_acc did not improve from 0.96939
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.003125.
# 50000/50000 [==============================] - 37s 746us/step - loss: 6.9233e-04 - acc: 0.9998 - val_loss: 0.1529 - val_acc: 0.9691
#
# Epoch 00050: val_acc did not improve from 0.96939
# Model took 1867.41 seconds to train
# Accuracy on test data is: 84.34
# 2019-06-16 16:31:24.094109

# %% [markdown]
# ## Run3

# %%
# train the model
start = time.time()

# Train the model
history = model.fit(train_features,       
                    train_labels,
                    batch_size=batch_size,
                    epochs=50,                  
                    validation_data=(test_features, test_labels),
                    callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
                    verbose=1)


end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(history)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))

import datetime
print(datetime.datetime.now())
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 38s 756us/step - loss: 0.0284 - acc: 0.9900 - val_loss: 0.1466 - val_acc: 0.9612
#
# Epoch 00001: val_acc did not improve from 0.96939
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 739us/step - loss: 0.0199 - acc: 0.9925 - val_loss: 0.1510 - val_acc: 0.9605
#
# Epoch 00002: val_acc did not improve from 0.96939
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.0172 - acc: 0.9936 - val_loss: 0.1630 - val_acc: 0.9604
#
# Epoch 00003: val_acc did not improve from 0.96939
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0163 - acc: 0.9940 - val_loss: 0.1797 - val_acc: 0.9580
#
# Epoch 00004: val_acc did not improve from 0.96939
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0155 - acc: 0.9943 - val_loss: 0.1563 - val_acc: 0.9601
#
# Epoch 00005: val_acc did not improve from 0.96939
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0128 - acc: 0.9953 - val_loss: 0.1723 - val_acc: 0.9607
#
# Epoch 00006: val_acc did not improve from 0.96939
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0131 - acc: 0.9951 - val_loss: 0.1677 - val_acc: 0.9621
#
# Epoch 00007: val_acc did not improve from 0.96939
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0121 - acc: 0.9957 - val_loss: 0.1401 - val_acc: 0.9642
#
# Epoch 00008: val_acc did not improve from 0.96939
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0100 - acc: 0.9963 - val_loss: 0.1540 - val_acc: 0.9629
#
# Epoch 00009: val_acc did not improve from 0.96939
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0054 - acc: 0.9982 - val_loss: 0.1414 - val_acc: 0.9677
#
# Epoch 00010: val_acc did not improve from 0.96939
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0029 - acc: 0.9991 - val_loss: 0.1438 - val_acc: 0.9680
#
# Epoch 00011: val_acc did not improve from 0.96939
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0029 - acc: 0.9991 - val_loss: 0.1559 - val_acc: 0.9665
#
# Epoch 00012: val_acc did not improve from 0.96939
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.1481 - val_acc: 0.9676
#
# Epoch 00013: val_acc did not improve from 0.96939
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0027 - acc: 0.9991 - val_loss: 0.1470 - val_acc: 0.9679
#
# Epoch 00014: val_acc did not improve from 0.96939
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0022 - acc: 0.9993 - val_loss: 0.1532 - val_acc: 0.9677
#
# Epoch 00015: val_acc did not improve from 0.96939
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0021 - acc: 0.9993 - val_loss: 0.1574 - val_acc: 0.9675
#
# Epoch 00016: val_acc did not improve from 0.96939
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 744us/step - loss: 0.0015 - acc: 0.9995 - val_loss: 0.1581 - val_acc: 0.9675
#
# Epoch 00017: val_acc did not improve from 0.96939
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0018 - acc: 0.9994 - val_loss: 0.1601 - val_acc: 0.9675
#
# Epoch 00018: val_acc did not improve from 0.96939
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0019 - acc: 0.9994 - val_loss: 0.1547 - val_acc: 0.9678
#
# Epoch 00019: val_acc did not improve from 0.96939
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0014 - acc: 0.9996 - val_loss: 0.1541 - val_acc: 0.9686
#
# Epoch 00020: val_acc did not improve from 0.96939
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 9.8912e-04 - acc: 0.9997 - val_loss: 0.1535 - val_acc: 0.9692
#
# Epoch 00021: val_acc did not improve from 0.96939
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 0.0012 - acc: 0.9996 - val_loss: 0.1536 - val_acc: 0.9692
#
# Epoch 00022: val_acc did not improve from 0.96939
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 744us/step - loss: 9.5287e-04 - acc: 0.9997 - val_loss: 0.1554 - val_acc: 0.9689
#
# Epoch 00023: val_acc did not improve from 0.96939
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 744us/step - loss: 9.1342e-04 - acc: 0.9997 - val_loss: 0.1551 - val_acc: 0.9692
#
# Epoch 00024: val_acc did not improve from 0.96939
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 8.3246e-04 - acc: 0.9998 - val_loss: 0.1556 - val_acc: 0.9693
#
# Epoch 00025: val_acc did not improve from 0.96939
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 744us/step - loss: 8.5869e-04 - acc: 0.9997 - val_loss: 0.1592 - val_acc: 0.9680
#
# Epoch 00026: val_acc did not improve from 0.96939
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 8.7040e-04 - acc: 0.9997 - val_loss: 0.1571 - val_acc: 0.9686
#
# Epoch 00027: val_acc did not improve from 0.96939
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 743us/step - loss: 7.0264e-04 - acc: 0.9998 - val_loss: 0.1569 - val_acc: 0.9692
#
# Epoch 00028: val_acc did not improve from 0.96939
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 37s 744us/step - loss: 8.7210e-04 - acc: 0.9998 - val_loss: 0.1572 - val_acc: 0.9698
#
# Epoch 00029: val_acc improved from 0.96939 to 0.96984, saving model to best_new_model.h5
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 6.7812e-04 - acc: 0.9998 - val_loss: 0.1556 - val_acc: 0.9697
#
# Epoch 00030: val_acc did not improve from 0.96984
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 6.8299e-04 - acc: 0.9998 - val_loss: 0.1553 - val_acc: 0.9697
#
# Epoch 00031: val_acc did not improve from 0.96984
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 6.4703e-04 - acc: 0.9998 - val_loss: 0.1552 - val_acc: 0.9699
#
# Epoch 00032: val_acc improved from 0.96984 to 0.96987, saving model to best_new_model.h5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 6.2067e-04 - acc: 0.9998 - val_loss: 0.1580 - val_acc: 0.9696
#
# Epoch 00033: val_acc did not improve from 0.96987
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 5.5198e-04 - acc: 0.9999 - val_loss: 0.1566 - val_acc: 0.9698
#
# Epoch 00034: val_acc did not improve from 0.96987
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 4.5901e-04 - acc: 0.9999 - val_loss: 0.1558 - val_acc: 0.9698
#
# Epoch 00035: val_acc did not improve from 0.96987
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 4.7474e-04 - acc: 0.9999 - val_loss: 0.1560 - val_acc: 0.9700
#
# Epoch 00036: val_acc improved from 0.96987 to 0.96995, saving model to best_new_model.h5
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 744us/step - loss: 5.4782e-04 - acc: 0.9999 - val_loss: 0.1566 - val_acc: 0.9698
#
# Epoch 00037: val_acc did not improve from 0.96995
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 5.2881e-04 - acc: 0.9999 - val_loss: 0.1565 - val_acc: 0.9699
#
# Epoch 00038: val_acc did not improve from 0.96995
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 4.1377e-04 - acc: 0.9999 - val_loss: 0.1570 - val_acc: 0.9696
#
# Epoch 00039: val_acc did not improve from 0.96995
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 747us/step - loss: 3.5548e-04 - acc: 0.9999 - val_loss: 0.1564 - val_acc: 0.9700
#
# Epoch 00040: val_acc improved from 0.96995 to 0.97003, saving model to best_new_model.h5
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 38s 751us/step - loss: 4.6065e-04 - acc: 0.9999 - val_loss: 0.1556 - val_acc: 0.9701
#
# Epoch 00041: val_acc improved from 0.97003 to 0.97011, saving model to best_new_model.h5
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 745us/step - loss: 4.7285e-04 - acc: 0.9999 - val_loss: 0.1559 - val_acc: 0.9707
#
# Epoch 00042: val_acc improved from 0.97011 to 0.97073, saving model to best_new_model.h5
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 745us/step - loss: 3.6241e-04 - acc: 0.9999 - val_loss: 0.1567 - val_acc: 0.9704
#
# Epoch 00043: val_acc did not improve from 0.97073
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 4.6072e-04 - acc: 0.9999 - val_loss: 0.1570 - val_acc: 0.9702
#
# Epoch 00044: val_acc did not improve from 0.97073
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 4.8944e-04 - acc: 0.9999 - val_loss: 0.1572 - val_acc: 0.9701
#
# Epoch 00045: val_acc did not improve from 0.97073
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 744us/step - loss: 4.7367e-04 - acc: 0.9999 - val_loss: 0.1565 - val_acc: 0.9702
#
# Epoch 00046: val_acc did not improve from 0.97073
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 748us/step - loss: 4.4898e-04 - acc: 0.9999 - val_loss: 0.1563 - val_acc: 0.9702
#
# Epoch 00047: val_acc did not improve from 0.97073
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 4.6049e-04 - acc: 0.9999 - val_loss: 0.1561 - val_acc: 0.9700
#
# Epoch 00048: val_acc did not improve from 0.97073
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 37s 746us/step - loss: 3.6467e-04 - acc: 0.9999 - val_loss: 0.1568 - val_acc: 0.9703
#
# Epoch 00049: val_acc did not improve from 0.97073
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.003125.
# 50000/50000 [==============================] - 37s 743us/step - loss: 4.2190e-04 - acc: 0.9999 - val_loss: 0.1574 - val_acc: 0.9702
#
# Epoch 00050: val_acc did not improve from 0.97073
# Model took 1861.02 seconds to train
# Accuracy on test data is: 84.99
# 2019-06-16 17:13:14.777557

# %% [markdown]
# ##Summary:
#
#
#
# A new network using Functional API  in impelemented using Normal Convolution, Separable Convolution, Depthwise Convolution and Grouped Convolution with different kernel sizes. The network was trained from 50 epochs, the total prameters of the network and validation accuracy is as mentioned below:
#
#
# > * Total params: 1,284,264
# > * Trainable params: 1,283,476
# > * Non-trainable params: 788
# > > *  Base: Validation Accuracy: **96.68%**
# > > *  Run1: Validation Accuracy: **96.773%**
# > > *  Run2: Validation Accuracy: **96.939%**
# > > *  Run3: Validation Accuracy: **97.073%**
#
#
# Thank you!
