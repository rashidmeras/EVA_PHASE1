# Epoch 74/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2770 - acc: 0.9104 - val_loss: 0.5820 - val_acc: 0.8317
# Epoch 75/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2743 - acc: 0.9121 - val_loss: 0.6171 - val_acc: 0.8288
# Epoch 76/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2766 - acc: 0.9111 - val_loss: 0.6060 - val_acc: 0.8272
# Epoch 77/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2747 - acc: 0.9106 - val_loss: 0.5762 - val_acc: 0.8330
# Epoch 78/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2625 - acc: 0.9156 - val_loss: 0.5956 - val_acc: 0.8358
# Epoch 79/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2623 - acc: 0.9162 - val_loss: 0.5880 - val_acc: 0.8272
# Epoch 80/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2755 - acc: 0.9136 - val_loss: 0.6017 - val_acc: 0.8382
# Epoch 81/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2655 - acc: 0.9157 - val_loss: 0.5830 - val_acc: 0.8339
# Epoch 82/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2595 - acc: 0.9180 - val_loss: 0.5913 - val_acc: 0.8365
# Epoch 83/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2619 - acc: 0.9169 - val_loss: 0.6321 - val_acc: 0.8308
# Epoch 84/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2557 - acc: 0.9180 - val_loss: 0.6006 - val_acc: 0.8346
# Epoch 85/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2602 - acc: 0.9161 - val_loss: 0.6077 - val_acc: 0.8380
# Epoch 86/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2610 - acc: 0.9165 - val_loss: 0.5870 - val_acc: 0.8354
# Epoch 87/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2638 - acc: 0.9166 - val_loss: 0.6143 - val_acc: 0.8325
# Epoch 88/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2544 - acc: 0.9190 - val_loss: 0.6033 - val_acc: 0.8377
# Epoch 89/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2594 - acc: 0.9171 - val_loss: 0.6056 - val_acc: 0.8374
# Epoch 90/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2532 - acc: 0.9183 - val_loss: 0.5997 - val_acc: 0.8360
# Epoch 91/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2562 - acc: 0.9194 - val_loss: 0.6120 - val_acc: 0.8356
# Epoch 92/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2482 - acc: 0.9223 - val_loss: 0.6242 - val_acc: 0.8339
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2519 - acc: 0.9217 - val_loss: 0.6216 - val_acc: 0.8326
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2575 - acc: 0.9188 - val_loss: 0.6064 - val_acc: 0.8338
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2591 - acc: 0.9197 - val_loss: 0.6077 - val_acc: 0.8374
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2562 - acc: 0.9199 - val_loss: 0.6074 - val_acc: 0.8362
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2409 - acc: 0.9231 - val_loss: 0.6298 - val_acc: 0.8332
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2625 - acc: 0.9183 - val_loss: 0.6082 - val_acc: 0.8311
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2511 - acc: 0.9202 - val_loss: 0.6101 - val_acc: 0.8358
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2489 - acc: 0.9227 - val_loss: 0.5991 - val_acc: 0.8368
# Model took 912.46 seconds to train
# Accuracy on test data is: 83.68

# %% [markdown]
# Part 1 - Analysis of the Crude Network:
#
# * Total params: 1,172,410
# * Batch Size = 128
# * Epoch = 100
# > * Validation accuracy = 83.55%

# %% [markdown]
# ##Part 2 - Modified Network

# %%
# Define the model
model = Sequential()

model.add(Convolution2D(32, 3, 3, activation='relu', use_bias=False, border_mode='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(32, 32, 3))) 
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, border_mode='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(128, 3, 3, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(16, 1, 1, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

#Layer: Max-Pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, border_mode='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(128, 3, 3, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(16, 1, 1, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

#Layer: Max-Pooling layer
model.add(MaxPooling2D(pool_size=(2, 2))) 

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, border_mode='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, activation='relu', use_bias=False, border_mode='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(128, 3, 3, activation='relu', use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(num_classes, 3, 3, use_bias=False, kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.1))

#Layer9: Flatten & activation
model.add(Flatten())
model.add(Activation('softmax'))

#Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg..., padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (1, 1), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (1, 1), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", use_bias=False, kernel_regularizer=<keras.reg...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 32, 32, 32)        864
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 64)        18432
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 30, 30, 64)        36864
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 30, 30, 64)        256
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 28, 28, 128)       73728
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 16)        2048
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 14, 14, 64)        9216
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 12, 12, 64)        36864
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 10, 10, 128)       73728
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 10, 10, 16)        2048
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 10, 10, 16)        64
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 10, 10, 16)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 5, 5, 64)          9216
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 5, 5, 64)          36864
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 3, 3, 128)         73728
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 3, 3, 128)         512
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 1, 10)          11520
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 1, 1, 10)          40
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 388,488
# Trainable params: 386,804
# Non-trainable params: 1,684
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (3, 3), use_bias=False, kernel_regularizer=<keras.reg...)`

# %% [markdown]
# ##Image Normalization

# %%
# train_features 
# test_features 
# # convert class labels to binary class labels
# train_labels 
# test_labels 

# confirm scale of pixels
print('Train min=%.3f, max=%.3f' % (train_features.min(), train_features.max()))
print('Test min=%.3f, max=%.3f' % (test_features.min(), test_features.max()))

batch_size = 128

# create generator that centers pixel values
datagen = ImageDataGenerator(     
                              featurewise_center=True, 
                              featurewise_std_normalization=True,
                              samplewise_center=True,
                              samplewise_std_normalization=True
                             )

# calculate mean on training dataset
datagen.fit(train_features)

# print('Data Generator mean=%.3f, std=%.3f' % (datagen.mean, datagen.std))

# prepare an iterators to scale images
train_iterator = datagen.flow(train_features, train_labels, batch_size, shuffle=False)
test_iterator = datagen.flow(test_features, test_labels, batch_size, shuffle=False)

print('Batches train=%d, test=%d' % (len(train_iterator), len(test_iterator)))
# Out:
# Train min=0.000, max=1.000
# Test min=0.000, max=1.000
# Batches train=391, test=79

# %%
import math
import numpy as np
from keras.optimizers import Adam, SGD
from keras.callbacks import LearningRateScheduler

# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

sgd = SGD(lr=0.0, momentum=0.9, decay=0.0, nesterov=False)
  
model.compile(optimizer= sgd,
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

save_mcp = ModelCheckpoint('best_new_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# train the model
start = time.time()
# Train the model
history = model.fit_generator(train_iterator, 
                              steps_per_epoch=len(train_iterator), 
                              epochs=50, 
                              validation_data=(test_features, test_labels),
                              callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
                              verbose=1)

end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(history)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 33s 85ms/step - loss: 0.8505 - acc: 0.9009 - val_loss: 0.3704 - val_acc: 0.9000
#
# Epoch 00001: val_acc improved from -inf to 0.90000, saving model to best_new_model.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.3108 - acc: 0.9018 - val_loss: 0.3971 - val_acc: 0.9000
#
# Epoch 00002: val_acc did not improve from 0.90000
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3186 - acc: 0.9051 - val_loss: 0.4199 - val_acc: 0.9000
#
# Epoch 00003: val_acc did not improve from 0.90000
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3229 - acc: 0.9062 - val_loss: 0.4066 - val_acc: 0.9000
#
# Epoch 00004: val_acc did not improve from 0.90000
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3200 - acc: 0.9067 - val_loss: 0.4057 - val_acc: 0.9000
#
# Epoch 00005: val_acc did not improve from 0.90000
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3197 - acc: 0.9063 - val_loss: 0.4356 - val_acc: 0.9000
#
# Epoch 00006: val_acc did not improve from 0.90000
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3214 - acc: 0.9058 - val_loss: 0.4871 - val_acc: 0.9000
#
# Epoch 00007: val_acc did not improve from 0.90000
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3207 - acc: 0.9061 - val_loss: 0.4208 - val_acc: 0.9000
#
# Epoch 00008: val_acc did not improve from 0.90000
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.1.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.3211 - acc: 0.9064 - val_loss: 0.4544 - val_acc: 0.9000
#
# Epoch 00009: val_acc did not improve from 0.90000
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2904 - acc: 0.9122 - val_loss: 0.5066 - val_acc: 0.8200
#
# Epoch 00010: val_acc did not improve from 0.90000
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2928 - acc: 0.9148 - val_loss: 0.4047 - val_acc: 0.9000
#
# Epoch 00011: val_acc did not improve from 0.90000
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2917 - acc: 0.9159 - val_loss: 0.4543 - val_acc: 0.8999
#
# Epoch 00012: val_acc did not improve from 0.90000
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2955 - acc: 0.9157 - val_loss: 0.4131 - val_acc: 0.9000
#
# Epoch 00013: val_acc did not improve from 0.90000
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2974 - acc: 0.9166 - val_loss: 0.9233 - val_acc: 0.8200
#
# Epoch 00014: val_acc did not improve from 0.90000
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2953 - acc: 0.9170 - val_loss: 0.5317 - val_acc: 0.8317
#
# Epoch 00015: val_acc did not improve from 0.90000
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2971 - acc: 0.9170 - val_loss: 0.4603 - val_acc: 0.9000
#
# Epoch 00016: val_acc did not improve from 0.90000
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2973 - acc: 0.9170 - val_loss: 0.5015 - val_acc: 0.8323
#
# Epoch 00017: val_acc did not improve from 0.90000
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2979 - acc: 0.9167 - val_loss: 0.5466 - val_acc: 0.8200
#
# Epoch 00018: val_acc did not improve from 0.90000
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.05.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2964 - acc: 0.9173 - val_loss: 0.4979 - val_acc: 0.9000
#
# Epoch 00019: val_acc did not improve from 0.90000
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2635 - acc: 0.9233 - val_loss: 0.4696 - val_acc: 0.9000
#
# Epoch 00020: val_acc did not improve from 0.90000
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2565 - acc: 0.9251 - val_loss: 0.4826 - val_acc: 0.9000
#
# Epoch 00021: val_acc did not improve from 0.90000
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2597 - acc: 0.9255 - val_loss: 0.4639 - val_acc: 0.9000
#
# Epoch 00022: val_acc did not improve from 0.90000
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2591 - acc: 0.9265 - val_loss: 0.5372 - val_acc: 0.8681
#
# Epoch 00023: val_acc did not improve from 0.90000
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2608 - acc: 0.9269 - val_loss: 0.4596 - val_acc: 0.9000
#
# Epoch 00024: val_acc did not improve from 0.90000
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2596 - acc: 0.9271 - val_loss: 0.4734 - val_acc: 0.9000
#
# Epoch 00025: val_acc did not improve from 0.90000
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2594 - acc: 0.9279 - val_loss: 0.6042 - val_acc: 0.8226
#
# Epoch 00026: val_acc did not improve from 0.90000
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2629 - acc: 0.9270 - val_loss: 0.4715 - val_acc: 0.8962
#
# Epoch 00027: val_acc did not improve from 0.90000
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2613 - acc: 0.9271 - val_loss: 0.5289 - val_acc: 0.8984
#
# Epoch 00028: val_acc did not improve from 0.90000
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.025.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2612 - acc: 0.9277 - val_loss: 0.4713 - val_acc: 0.8644
#
# Epoch 00029: val_acc did not improve from 0.90000
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 73ms/step - loss: 0.2287 - acc: 0.9345 - val_loss: 0.4261 - val_acc: 0.9000
#
# Epoch 00030: val_acc did not improve from 0.90000
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2232 - acc: 0.9354 - val_loss: 0.4989 - val_acc: 0.8200
#
# Epoch 00031: val_acc did not improve from 0.90000
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2238 - acc: 0.9358 - val_loss: 0.4251 - val_acc: 0.8999
#
# Epoch 00032: val_acc did not improve from 0.90000
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2233 - acc: 0.9363 - val_loss: 0.4663 - val_acc: 0.9000
#
# Epoch 00033: val_acc did not improve from 0.90000
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 75ms/step - loss: 0.2260 - acc: 0.9363 - val_loss: 0.4724 - val_acc: 0.9000
#
# Epoch 00034: val_acc did not improve from 0.90000
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 75ms/step - loss: 0.2267 - acc: 0.9365 - val_loss: 0.4559 - val_acc: 0.8997
#
# Epoch 00035: val_acc did not improve from 0.90000
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2250 - acc: 0.9370 - val_loss: 0.4575 - val_acc: 0.9000
#
# Epoch 00036: val_acc did not improve from 0.90000
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2273 - acc: 0.9368 - val_loss: 0.4472 - val_acc: 0.9000
#
# Epoch 00037: val_acc did not improve from 0.90000
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2252 - acc: 0.9375 - val_loss: 0.4932 - val_acc: 0.8921
#
# Epoch 00038: val_acc did not improve from 0.90000
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0125.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2261 - acc: 0.9373 - val_loss: 0.4978 - val_acc: 0.9000
#
# Epoch 00039: val_acc did not improve from 0.90000
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.2016 - acc: 0.9438 - val_loss: 0.5029 - val_acc: 0.8578
#
# Epoch 00040: val_acc did not improve from 0.90000
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1943 - acc: 0.9439 - val_loss: 0.5316 - val_acc: 0.8205
#
# Epoch 00041: val_acc did not improve from 0.90000
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1938 - acc: 0.9445 - val_loss: 0.6035 - val_acc: 0.8200
#
# Epoch 00042: val_acc did not improve from 0.90000
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1937 - acc: 0.9446 - val_loss: 0.4488 - val_acc: 0.8964
#
# Epoch 00043: val_acc did not improve from 0.90000
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1941 - acc: 0.9450 - val_loss: 0.6112 - val_acc: 0.8302
#
# Epoch 00044: val_acc did not improve from 0.90000
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1941 - acc: 0.9453 - val_loss: 0.5778 - val_acc: 0.8207
#
# Epoch 00045: val_acc did not improve from 0.90000
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1945 - acc: 0.9457 - val_loss: 0.5205 - val_acc: 0.8220
#
# Epoch 00046: val_acc did not improve from 0.90000
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1946 - acc: 0.9454 - val_loss: 0.5743 - val_acc: 0.8587
#
# Epoch 00047: val_acc did not improve from 0.90000
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1945 - acc: 0.9457 - val_loss: 0.5315 - val_acc: 0.8296
#
# Epoch 00048: val_acc did not improve from 0.90000
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00625.
# 391/391 [==============================] - 29s 74ms/step - loss: 0.1946 - acc: 0.9461 - val_loss: 0.6182 - val_acc: 0.8201
#
# Epoch 00049: val_acc did not improve from 0.90000
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.003125.
# 391/391 [==============================] - 29s 75ms/step - loss: 0.1744 - acc: 0.9521 - val_loss: 0.5973 - val_acc: 0.8218
#
# Epoch 00050: val_acc did not improve from 0.90000
# Model took 1451.10 seconds to train
# Accuracy on test data is: 10.13
