# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidmeras/EVA_PHASE1/blob/master/EVA_S6_Assignment_6A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EVA (M6) Session6 Assignment 6A:
#
# Objective:
#
#
#
# > After training the crude network, note down the accuracy as base accuracy for Epochs = 100
#
# > Fix the crude network by considering the following:
# > * remove dense
# > * add layers required to reach RF
# > * fix kernel scaleup and down (1x1)
# > * see if all dropouts are properly placed
# > * follow the guidelines discussed in the class
#
# Get accuracy more than the base accuracy in less number 100 epochs.

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(900) 
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D, Convolution2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Flatten 32x32x3 images to a 1024*3 vector for each image.
train_features = train_features.reshape(train_features.shape[0], 32, 32, 3)
test_features = test_features.reshape(test_features.shape[0], 32, 32, 3)

train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ##Image Normalization

# %%
# #Z-score (mean-std normalization) of images
# mean = np.mean(train_features,axis=(0,1,2,3))
# std = np.std(train_features,axis=(0,1,2,3))

# train_features = (train_features-mean)/(std+1e-7)
# test_features = (test_features-mean)/(std+1e-7)


# # confirm scale of pixels
# print('Train min=%.3f, max=%.3f' % (train_features.min(), train_features.max()))
# print('Test min=%.3f, max=%.3f' % (test_features.min(), test_features.max()))

batch_size = 64

# standardize images
def prep_standardize(train, test):
	# convert from integers to floats
	train_stan = train.astype('float32')
	test_stan  = test.astype('float32')
	# calculate statistics
	m = train_stan.mean()
	s = train_stan.std()
	# center datasets
	train_stan = (train_stan - m) / s
	test_stan  = (test_stan - m) / s
	# return normalized images
	return train_stan, test_stan

train_features, test_features = prep_standardize(train_features, test_features)

# # standardize test
# test_features = prep_standardize(train_features, test_features)

# # create generator that centers pixel values
# datagen = ImageDataGenerator(         
#                               featurewise_center=True, 
#                               featurewise_std_normalization=True
#                             )

# # calculate mean on training dataset
# datagen.fit(train_features)



# # print('Data Generator mean=%.3f, std=%.3f' % (datagen.mean, datagen.std)

# # prepare an iterators to scale images
# train_iterator = datagen.flow(train_features, train_labels, batch_size, shuffle=False)
# test_iterator = datagen.flow(test_features, test_labels, batch_size, shuffle=False)

# print('Batches train=%d, test=%d' % (len(train_iterator), len(test_iterator)))
print('Train min=%.3f, max=%.3f' % (train_features.min(), train_features.max()))
print('Test min=%.3f, max=%.3f' % (test_features.min(), test_features.max()))
# Out:
# Train min=-1.882, max=2.093
# Test min=-1.882, max=2.093

# %% [markdown]
# ##Crude Network:

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/100
# 390/390 [==============================] - 15s 38ms/step - loss: 1.7756 - acc: 0.3207 - val_loss: 1.3352 - val_acc: 0.5096
# Epoch 2/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.2455 - acc: 0.5534 - val_loss: 1.0041 - val_acc: 0.6393
# Epoch 3/100
# 390/390 [==============================] - 9s 22ms/step - loss: 1.0176 - acc: 0.6445 - val_loss: 0.8650 - val_acc: 0.7026
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0
100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2931 - acc: 0.9101 - val_loss: 0.6122 - val_acc: 0.8351
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2689 - acc: 0.9177 - val_loss: 0.6227 - val_acc: 0.8374
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2786 - acc: 0.9146 - val_loss: 0.6229 - val_acc: 0.8376
# Model took 898.58 seconds to train
# Accuracy on test data is: 83.76

# %% [markdown]
# Part 1 - Analysis of the Crude Network:
#
# * Total params: 1,172,410
# * Batch Size = 128
# * Epoch = 100
# > * Validation accuracy = 84.18%

# %% [markdown]
# ##Part 2 - Modified Network

# %%
# Define the model
model = Sequential()

model.add(Conv2D(32,  kernel_size=(3, 3), use_bias=False, padding='same', input_shape=(32, 32, 3))) 
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(16,  kernel_size=(1, 1), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

#Layer: Max-Pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(16,  kernel_size=(1, 1), use_bias=False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

#Layer: Max-Pooling layer
model.add(MaxPooling2D(pool_size=(2, 2))) 

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(64,  kernel_size=(3, 3), use_bias=False, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), use_bias=False))
model.add(Activation('relu'))

model.add(Conv2D(num_classes, kernel_size=(3, 3), use_bias=False))

#Layer: Flatten & activation
model.add(Flatten())
model.add(Activation('softmax'))

#Print model summary
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 64)        36864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 128)       73728
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 16)        2048
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 16)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 64)        9216
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 64)        36864
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# activation_7 (Activation)    (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 128)       73728
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# activation_8 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 16)        2048
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 10, 10, 16)        64
# _________________________________________________________________
# activation_9 (Activation)    (None, 10, 10, 16)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 10, 10, 16)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 64)          9216
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# activation_10 (Activation)   (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 64)          36864
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5, 5, 64)          256
# _________________________________________________________________
# activation_11 (Activation)   (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 128)         73728
# _________________________________________________________________
# activation_12 (Activation)   (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 10)          11520
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_13 (Activation)   (None, 10)                0
# =================================================================
# Total params: 387,936
# Trainable params: 386,528
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
import math
import numpy as np
from keras.optimizers import Adam, SGD, rmsprop
from keras.callbacks import LearningRateScheduler

# Define custom loss
def custom_loss(actual,predicted):
    sqr_w = 0
    lamda = 1e-2
    
    for layer in model.layers:
       sqr_w = sqr_w + np.sum(np.sum(np.sum(np.square(layer.get_weights()))))
        
    l2_regularization = (lamda*sqr_w)/2*(batch_size)    
    loss = K.categorical_crossentropy(actual,predicted) + l2_regularization
    # Return a function
    return loss
  
# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

sgd = SGD(lr=0.0, momentum=0.9, decay=0.0, nesterov=False)
  
model.compile(optimizer= sgd,
              loss = custom_loss,
#               loss = 'binary_crossentropy',
              metrics=['accuracy'])

save_mcp = ModelCheckpoint('best_new_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# train the model
start = time.time()
# Train the model


# history = model.fit_generator(train_iterator, 
#                               steps_per_epoch=len(train_iterator),             
#                               epochs=50, 
#                               validation_data=(test_features, test_labels),
#                               callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
#                               verbose=1)

history = model.fit(train_features,       
                    train_labels,
                    batch_size=batch_size,
                    epochs=50,                  
                    validation_data=(test_features, test_labels),
                    callbacks=[save_mcp, LearningRateScheduler(step_decay, verbose=1)], 
                    verbose=1)


end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(history)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 67s 1ms/step - loss: 651.9341 - acc: 0.3662 - val_loss: 651.7755 - val_acc: 0.4322
#
# Epoch 00001: val_acc improved from -inf to 0.43220, saving model to best_new_model.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 651.5369 - acc: 0.5320 - val_loss: 651.5778 - val_acc: 0.5130
#
# Epoch 00002: val_acc improved from 0.43220 to 0.51300, saving model to best_new_model.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 64s 1ms/step - loss: 651.3425 - acc: 0.6034 - val_loss: 651.3717 - val_acc: 0.6062
#
# Epoch 00003: val_acc improved from 0.51300 to 0.60620, saving model to best_new_model.h5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 64s 1ms/step - loss: 651.2225 - acc: 0.6484 - val_loss: 651.1968 - val_acc: 0.6521
#
# Epoch 00004: val_acc improved from 0.60620 to 0.65210, saving model to best_new_model.h5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 651.1343 - acc: 0.6845 - val_loss: 651.3772 - val_acc: 0.6208
#
# Epoch 00005: val_acc did not improve from 0.65210
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 64s 1ms/step - loss: 651.0667 - acc: 0.7082 - val_loss: 651.1149 - val_acc: 0.6975
#
# Epoch 00006: val_acc improved from 0.65210 to 0.69750, saving model to best_new_model.h5
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 651.0147 - acc: 0.7285 - val_loss: 651.0951 - val_acc: 0.7035
#
# Epoch 00007: val_acc improved from 0.69750 to 0.70350, saving model to best_new_model.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 64s 1ms/step - loss: 650.9701 - acc: 0.7422 - val_loss: 651.0403 - val_acc: 0.7237
#
# Epoch 00008: val_acc improved from 0.70350 to 0.72370, saving model to best_new_model.h5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.1.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.9341 - acc: 0.7554 - val_loss: 651.0459 - val_acc: 0.7132
#
# Epoch 00009: val_acc did not improve from 0.72370
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.8175 - acc: 0.7941 - val_loss: 650.9151 - val_acc: 0.7609
#
# Epoch 00010: val_acc improved from 0.72370 to 0.76090, saving model to best_new_model.h5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7832 - acc: 0.8066 - val_loss: 650.9379 - val_acc: 0.7549
#
# Epoch 00011: val_acc did not improve from 0.76090
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7637 - acc: 0.8136 - val_loss: 650.8978 - val_acc: 0.7677
#
# Epoch 00012: val_acc improved from 0.76090 to 0.76770, saving model to best_new_model.h5
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7504 - acc: 0.8166 - val_loss: 650.9000 - val_acc: 0.7672
#
# Epoch 00013: val_acc did not improve from 0.76770
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7258 - acc: 0.8253 - val_loss: 650.8815 - val_acc: 0.7808
#
# Epoch 00014: val_acc improved from 0.76770 to 0.78080, saving model to best_new_model.h5
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7180 - acc: 0.8284 - val_loss: 650.8754 - val_acc: 0.7819
#
# Epoch 00015: val_acc improved from 0.78080 to 0.78190, saving model to best_new_model.h5
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.7065 - acc: 0.8322 - val_loss: 650.8714 - val_acc: 0.7808
#
# Epoch 00016: val_acc did not improve from 0.78190
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.6957 - acc: 0.8357 - val_loss: 650.8360 - val_acc: 0.7922
#
# Epoch 00017: val_acc improved from 0.78190 to 0.79220, saving model to best_new_model.h5
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.6830 - acc: 0.8400 - val_loss: 650.8054 - val_acc: 0.8015
#
# Epoch 00018: val_acc improved from 0.79220 to 0.80150, saving model to best_new_model.h5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.05.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.6719 - acc: 0.8437 - val_loss: 650.9166 - val_acc: 0.7672
#
# Epoch 00019: val_acc did not improve from 0.80150
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.6144 - acc: 0.8635 - val_loss: 650.8133 - val_acc: 0.8084
#
# Epoch 00020: val_acc improved from 0.80150 to 0.80840, saving model to best_new_model.h5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5907 - acc: 0.8716 - val_loss: 650.8300 - val_acc: 0.8006
#
# Epoch 00021: val_acc did not improve from 0.80840
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5783 - acc: 0.8751 - val_loss: 650.8615 - val_acc: 0.7961
#
# Epoch 00022: val_acc did not improve from 0.80840
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 64s 1ms/step - loss: 650.5697 - acc: 0.8793 - val_loss: 650.8398 - val_acc: 0.8021
#
# Epoch 00023: val_acc did not improve from 0.80840
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5612 - acc: 0.8804 - val_loss: 650.8709 - val_acc: 0.7895
#
# Epoch 00024: val_acc did not improve from 0.80840
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5609 - acc: 0.8807 - val_loss: 650.8437 - val_acc: 0.8072
#
# Epoch 00025: val_acc did not improve from 0.80840
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5490 - acc: 0.8843 - val_loss: 650.8443 - val_acc: 0.8021
#
# Epoch 00026: val_acc did not improve from 0.80840
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5475 - acc: 0.8844 - val_loss: 650.8451 - val_acc: 0.8009
#
# Epoch 00027: val_acc did not improve from 0.80840
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5404 - acc: 0.8882 - val_loss: 650.8068 - val_acc: 0.8123
#
# Epoch 00028: val_acc improved from 0.80840 to 0.81230, saving model to best_new_model.h5
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.025.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5373 - acc: 0.8888 - val_loss: 650.8244 - val_acc: 0.8103
#
# Epoch 00029: val_acc did not improve from 0.81230
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.5000 - acc: 0.9015 - val_loss: 650.8177 - val_acc: 0.8147
#
# Epoch 00030: val_acc improved from 0.81230 to 0.81470, saving model to best_new_model.h5
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4901 - acc: 0.9062 - val_loss: 650.8019 - val_acc: 0.8208
#
# Epoch 00031: val_acc improved from 0.81470 to 0.82080, saving model to best_new_model.h5
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4820 - acc: 0.9089 - val_loss: 650.8009 - val_acc: 0.8207
#
# Epoch 00032: val_acc did not improve from 0.82080
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4761 - acc: 0.9121 - val_loss: 650.8073 - val_acc: 0.8224
#
# Epoch 00033: val_acc improved from 0.82080 to 0.82240, saving model to best_new_model.h5
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4758 - acc: 0.9107 - val_loss: 650.8254 - val_acc: 0.8165
#
# Epoch 00034: val_acc did not improve from 0.82240
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4691 - acc: 0.9130 - val_loss: 650.8171 - val_acc: 0.8225
#
# Epoch 00035: val_acc improved from 0.82240 to 0.82250, saving model to best_new_model.h5
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4656 - acc: 0.9150 - val_loss: 650.8136 - val_acc: 0.8209
#
# Epoch 00036: val_acc did not improve from 0.82250
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4655 - acc: 0.9135 - val_loss: 650.8413 - val_acc: 0.8137
#
# Epoch 00037: val_acc did not improve from 0.82250
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4605 - acc: 0.9174 - val_loss: 650.8333 - val_acc: 0.8207
#
# Epoch 00038: val_acc did not improve from 0.82250
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4555 - acc: 0.9178 - val_loss: 650.8514 - val_acc: 0.8107
#
# Epoch 00039: val_acc did not improve from 0.82250
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4438 - acc: 0.9224 - val_loss: 650.8523 - val_acc: 0.8119
#
# Epoch 00040: val_acc did not improve from 0.82250
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4291 - acc: 0.9260 - val_loss: 650.8292 - val_acc: 0.8221
#
# Epoch 00041: val_acc did not improve from 0.82250
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4327 - acc: 0.9262 - val_loss: 650.8353 - val_acc: 0.8187
#
# Epoch 00042: val_acc did not improve from 0.82250
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4276 - acc: 0.9278 - val_loss: 650.8271 - val_acc: 0.8237
#
# Epoch 00043: val_acc improved from 0.82250 to 0.82370, saving model to best_new_model.h5
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4252 - acc: 0.9284 - val_loss: 650.8395 - val_acc: 0.8193
#
# Epoch 00044: val_acc did not improve from 0.82370
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4236 - acc: 0.9290 - val_loss: 650.8470 - val_acc: 0.8179
#
# Epoch 00045: val_acc did not improve from 0.82370
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4242 - acc: 0.9295 - val_loss: 650.8444 - val_acc: 0.8197
#
# Epoch 00046: val_acc did not improve from 0.82370
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4164 - acc: 0.9313 - val_loss: 650.8432 - val_acc: 0.8221
#
# Epoch 00047: val_acc did not improve from 0.82370
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4222 - acc: 0.9298 - val_loss: 650.8442 - val_acc: 0.8213
#
# Epoch 00048: val_acc did not improve from 0.82370
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.00625.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4184 - acc: 0.9319 - val_loss: 650.8386 - val_acc: 0.8220
#
# Epoch 00049: val_acc did not improve from 0.82370
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.003125.
# 50000/50000 [==============================] - 63s 1ms/step - loss: 650.4070 - acc: 0.9346 - val_loss: 650.8378 - val_acc: 0.8236
#
# Epoch 00050: val_acc did not improve from 0.82370
# Model took 3162.54 seconds to train
# Accuracy on test data is: 82.36

# %% [markdown]
# Analysis of the Modified Network:
#
# > * Total params: 388,488
# > * Trainable params: 386,804
# > * Non-trainable params: 1,684
# >> * Validation accuracy = 82.37%

# %% [markdown]
# ## Summary:
#
# > In this excercise we had a crude network that had an accuracy of 84.18% for Epochs = 100. This network was re-designed  ("Modified Network")  by  removing dense layer and adding layers required to reach the receptive fields. All the dropouts were placed correctly and Image normalization was added.
#
#
# > The "Modified Network" had a validation accuracy of **82.37%** for a total of 50 epoch.
